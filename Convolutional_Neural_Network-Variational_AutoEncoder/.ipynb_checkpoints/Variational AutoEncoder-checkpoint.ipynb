# %%
#example from https://medium.com/dataseries/variational-autoencoder-with-pytorch-2d359cbf027b

import matplotlib.pyplot as plt # plotting library
import numpy as np # this module is useful to work with numerical arrays
import pandas as pd 
import random 
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim

data_dir = 'dataset'

train_dataset = torchvision.datasets.MNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.MNIST(data_dir, train=False, download=True)

train_transform = transforms.Compose([
transforms.ToTensor(),
])

test_transform = transforms.Compose([
transforms.ToTensor(),
])

train_dataset.transform = train_transform
test_dataset.transform = test_transform

m=len(train_dataset)

train_data, val_data = random_split(train_dataset, [int(m-m*0.2), int(m*0.2)])
batch_size=256

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to dataset\MNIST\raw\train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting dataset\MNIST\raw\train-images-idx3-ubyte.gz to dataset\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to dataset\MNIST\raw\train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting dataset\MNIST\raw\train-labels-idx1-ubyte.gz to dataset\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to dataset\MNIST\raw\t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting dataset\MNIST\raw\t10k-images-idx3-ubyte.gz to dataset\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to dataset\MNIST\raw\t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting dataset\MNIST\raw\t10k-labels-idx1-ubyte.gz to dataset\MNIST\raw

# %%
class VariationalEncoder(nn.Module):
    def __init__(self, latent_dims):  
        super(VariationalEncoder, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, 3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(8, 16, 3, stride=2, padding=1)
        self.batch2 = nn.BatchNorm2d(16)
        self.conv3 = nn.Conv2d(16, 32, 3, stride=2, padding=0)  
        self.linear1 = nn.Linear(3*3*32, 128)
        self.linear2 = nn.Linear(128, latent_dims)
        self.linear3 = nn.Linear(128, latent_dims)

        self.N = torch.distributions.Normal(0, 1)
        self.N.loc = self.N.loc.cuda() # hack to get sampling on the GPU
        self.N.scale = self.N.scale.cuda()
        self.kl = 0

    def forward(self, x):
        x = x.to(device)
        x = F.relu(self.conv1(x))
        x = F.relu(self.batch2(self.conv2(x)))
        x = F.relu(self.conv3(x))
        x = torch.flatten(x, start_dim=1)
        x = F.relu(self.linear1(x))
        mu =  self.linear2(x)
        sigma = torch.exp(self.linear3(x))
        z = mu + sigma*self.N.sample(mu.shape)
        self.kl = (sigma**2 + mu**2 - torch.log(sigma) - 1/2).sum()
        return z

# %%
class Decoder(nn.Module):
    
    def __init__(self, latent_dims):
        super().__init__()

        self.decoder_lin = nn.Sequential(
            nn.Linear(latent_dims, 128),
            nn.ReLU(True),
            nn.Linear(128, 3 * 3 * 32),
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(32, 3, 3))

        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose2d(32, 16, 3, stride=2, output_padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.ConvTranspose2d(16, 8, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            nn.ConvTranspose2d(8, 1, 3, stride=2, padding=1, output_padding=1)
        )
        
    def forward(self, x):
        x = self.decoder_lin(x)
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        x = torch.sigmoid(x)
        return x

# %%
class VariationalAutoencoder(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = VariationalEncoder(latent_dims)
        self.decoder = Decoder(latent_dims)

    def forward(self, x):
        x = x.to(device)
        z = self.encoder(x)
        return self.decoder(z)

# %%
### Set the random seed for reproducible results
torch.manual_seed(0)

d = 4

vae = VariationalAutoencoder(latent_dims=d)

lr = 1e-3 

optim = torch.optim.Adam(vae.parameters(), lr=lr, weight_decay=1e-5)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

vae.to(device)
# Out:
# Selected device: cuda
# VariationalAutoencoder(
#   (encoder): VariationalEncoder(
#     (conv1): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (batch2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (linear1): Linear(in_features=288, out_features=128, bias=True)
#     (linear2): Linear(in_features=128, out_features=4, bias=True)
#     (linear3): Linear(in_features=128, out_features=4, bias=True)
#   )
#   (decoder): Decoder(
#     (decoder_lin): Sequential(
#       (0): Linear(in_features=4, out_features=128, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=128, out_features=288, bias=True)
#       (3): ReLU(inplace=True)
#     )
#     (unflatten): Unflatten(dim=1, unflattened_size=(32, 3, 3))
#     (decoder_conv): Sequential(
#       (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     )
#   )
# )

# %%
### Training function
def train_epoch(vae, device, dataloader, optimizer):
    # Set train mode for both the encoder and the decoder
    vae.train()
    train_loss = 0.0
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for x, _ in dataloader: 
        # Move tensor to the proper device
        x = x.to(device)
        x_hat = vae(x)
        # Evaluate loss
        loss = ((x - x_hat)**2).sum() + vae.encoder.kl

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        print('\t partial train loss (single batch): %f' % (loss.item()))
        train_loss+=loss.item()

    return train_loss / len(dataloader.dataset)

# %%
### Testing function
def test_epoch(vae, device, dataloader):
    # Set evaluation mode for encoder and decoder
    vae.eval()
    val_loss = 0.0
    with torch.no_grad(): # No need to track the gradients
        for x, _ in dataloader:
            # Move tensor to the proper device
            x = x.to(device)
            # Encode data
            encoded_data = vae.encoder(x)
            # Decode data
            x_hat = vae(x)
            loss = ((x - x_hat)**2).sum() + vae.encoder.kl
            val_loss += loss.item()

    return val_loss / len(dataloader.dataset)

# %%
def plot_ae_outputs(encoder,decoder,n=10):
    plt.figure(figsize=(16,4.5))
    targets = test_dataset.targets.numpy()
    t_idx = {i:np.where(targets==i)[0][0] for i in range(n)}
    for i in range(n):
      ax = plt.subplot(2,n,i+1)
      img = test_dataset[t_idx[i]][0].unsqueeze(0).to(device)
      encoder.eval()
      decoder.eval()
      with torch.no_grad():
         rec_img  = decoder(encoder(img))
      plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)  
      if i == n//2:
        ax.set_title('Original images')
      ax = plt.subplot(2, n, i + 1 + n)
      plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')  
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)  
      if i == n//2:
         ax.set_title('Reconstructed images')
    plt.show()

# %%
num_epochs = 50

for epoch in range(num_epochs):
   train_loss = train_epoch(vae,device,train_loader,optim)
   val_loss = test_epoch(vae,device,valid_loader)
   print('\n EPOCH {}/{} \t train loss {:.3f} \t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))
   plot_ae_outputs(vae.encoder,vae.decoder,n=10)
# Out:
# 	 partial train loss (single batch): 69286.617188
# 	 partial train loss (single batch): 68113.210938
# 	 partial train loss (single batch): 66300.320312
# 	 partial train loss (single batch): 64536.035156
# 	 partial train loss (single batch): 63799.003906
# 	 partial train loss (single batch): 62444.160156
# 	 partial train loss (single batch): 61440.382812
# 	 partial train loss (single batch): 60395.378906
# 	 partial train loss (single batch): 59339.957031
# 	 partial train loss (single batch): 59369.058594
# 	 partial train loss (single batch): 58748.800781
# 	 partial train loss (single batch): 58062.453125
# 	 partial train loss (single batch): 57493.890625
# 	 partial train loss (single batch): 57084.945312
# 	 partial train loss (single batch): 56780.835938
# 	 partial train loss (single batch): 56364.109375
# 	 partial train loss (single batch): 55630.644531
# 	 partial train loss (single batch): 55366.917969
# 	 partial train loss (single batch): 55015.867188
# 	 partial train loss (single batch): 54628.316406
# 	 partial train loss (single batch): 54678.093750
# 	 partial train loss (single batch): 53895.648438
# 	 partial train loss (single batch): 53662.714844
# 	 partial train loss (single batch): 53084.539062
# 	 partial train loss (single batch): 52878.562500
# 	 partial train loss (single batch): 52481.871094
# 	 partial train loss (single batch): 52035.035156
# 	 partial train loss (single batch): 51900.492188
# 	 partial train loss (single batch): 51707.738281
# 	 partial train loss (single batch): 51405.386719
# 	 partial train loss (single batch): 50747.968750
# 	 partial train loss (single batch): 50604.054688
# 	 partial train loss (single batch): 50135.058594
# 	 partial train loss (single batch): 49959.015625
# 	 partial train loss (single batch): 49391.714844
# 	 partial train loss (single batch): 49323.769531
# 	 partial train loss (single batch): 48840.929688
# 	 partial train loss (single batch): 48717.832031
# 	 partial train loss (single batch): 48281.933594
# 	 partial train loss (single batch): 47927.382812
# 	 partial train loss (single batch): 47531.003906
# 	 partial train loss (single batch): 47417.734375
# 	 partial train loss (single batch): 47048.246094
# 	 partial train loss (single batch): 46841.320312
# 	 partial train loss (single batch): 46523.398438
# 	 partial train loss (single batch): 46224.746094
# 	 partial train loss (single batch): 46019.101562
# 	 partial train loss (single batch): 45488.890625
# 	 partial train loss (single batch): 45420.062500
# 	 partial train loss (single batch): 45194.886719
# 	 partial train loss (single batch): 44678.011719
# 	 partial train loss (single batch): 44451.261719
# 	 partial train loss (single batch): 44411.515625
# 	 partial train loss (single batch): 43943.863281
# 	 partial train loss (single batch): 43642.937500
# 	 partial train loss (single batch): 43293.675781
# 	 partial train loss (single batch): 43091.117188
# 	 partial train loss (single batch): 42829.160156
# 	 partial train loss (single batch): 42481.648438
# 	 partial train loss (single batch): 42437.441406
# 	 partial train loss (single batch): 42035.054688
# 	 partial train loss (single batch): 41906.144531
# 	 partial train loss (single batch): 41565.535156
# 	 partial train loss (single batch): 41231.953125
# 	 partial train loss (single batch): 40910.785156
# 	 partial train loss (single batch): 40703.675781
# 	 partial train loss (single batch): 40684.664062
# 	 partial train loss (single batch): 40320.230469
# 	 partial train loss (single batch): 40008.570312
# 	 partial train loss (single batch): 39772.066406
# 	 partial train loss (single batch): 39460.070312
# 	 partial train loss (single batch): 39262.042969
# 	 partial train loss (single batch): 38846.679688
# 	 partial train loss (single batch): 38658.738281
# 	 partial train loss (single batch): 38449.886719
# 	 partial train loss (single batch): 38204.371094
# 	 partial train loss (single batch): 37941.703125
# 	 partial train loss (single batch): 37828.812500
# 	 partial train loss (single batch): 37574.093750
# 	 partial train loss (single batch): 37249.292969
# 	 partial train loss (single batch): 36906.804688
# 	 partial train loss (single batch): 36732.855469
# 	 partial train loss (single batch): 36428.195312
# 	 partial train loss (single batch): 36360.933594
# 	 partial train loss (single batch): 36078.792969
# 	 partial train loss (single batch): 35915.960938
# 	 partial train loss (single batch): 35615.304688
# 	 partial train loss (single batch): 35362.589844
# 	 partial train loss (single batch): 35110.718750
# 	 partial train loss (single batch): 34772.867188
# 	 partial train loss (single batch): 34594.238281
# 	 partial train loss (single batch): 34437.347656
# 	 partial train loss (single batch): 34029.382812
# 	 partial train loss (single batch): 33940.652344
# 	 partial train loss (single batch): 33829.660156
# 	 partial train loss (single batch): 33515.925781
# 	 partial train loss (single batch): 33236.246094
# 	 partial train loss (single batch): 32955.656250
# 	 partial train loss (single batch): 32884.996094
# 	 partial train loss (single batch): 32595.035156
# 	 partial train loss (single batch): 32443.796875
# 	 partial train loss (single batch): 32140.767578
# 	 partial train loss (single batch): 32105.597656
# 	 partial train loss (single batch): 31826.062500
# 	 partial train loss (single batch): 31493.294922
# 	 partial train loss (single batch): 31415.742188
# 	 partial train loss (single batch): 31038.332031
# 	 partial train loss (single batch): 30819.703125
# 	 partial train loss (single batch): 30705.402344
# 	 partial train loss (single batch): 30474.580078
# 	 partial train loss (single batch): 30377.193359
# 	 partial train loss (single batch): 30054.896484
# 	 partial train loss (single batch): 29969.527344
# 	 partial train loss (single batch): 29680.529297
# 	 partial train loss (single batch): 29509.710938
# 	 partial train loss (single batch): 29456.955078
# 	 partial train loss (single batch): 29207.216797
# 	 partial train loss (single batch): 29099.968750
# 	 partial train loss (single batch): 28839.615234
# 	 partial train loss (single batch): 28566.314453
# 	 partial train loss (single batch): 28330.218750
# 	 partial train loss (single batch): 28267.447266
# 	 partial train loss (single batch): 28008.738281
# 	 partial train loss (single batch): 27978.650391
# 	 partial train loss (single batch): 27711.361328
# 	 partial train loss (single batch): 27428.060547
# 	 partial train loss (single batch): 27515.201172
# 	 partial train loss (single batch): 27186.933594
# 	 partial train loss (single batch): 27162.912109
# 	 partial train loss (single batch): 26960.226562
# 	 partial train loss (single batch): 26693.962891
# 	 partial train loss (single batch): 26618.478516
# 	 partial train loss (single batch): 26402.382812
# 	 partial train loss (single batch): 26420.500000
# 	 partial train loss (single batch): 26008.408203
# 	 partial train loss (single batch): 25967.224609
# 	 partial train loss (single batch): 25733.125000
# 	 partial train loss (single batch): 25558.158203
# 	 partial train loss (single batch): 25434.029297
# 	 partial train loss (single batch): 25282.634766
# 	 partial train loss (single batch): 25104.818359
# 	 partial train loss (single batch): 24889.431641
# 	 partial train loss (single batch): 24783.617188
# 	 partial train loss (single batch): 24807.533203
# 	 partial train loss (single batch): 24690.212891
# 	 partial train loss (single batch): 24446.210938
# 	 partial train loss (single batch): 24031.091797
# 	 partial train loss (single batch): 24023.732422
# 	 partial train loss (single batch): 24015.896484
# 	 partial train loss (single batch): 23839.695312
# 	 partial train loss (single batch): 23764.808594
# 	 partial train loss (single batch): 23528.568359
# 	 partial train loss (single batch): 23597.478516
# 	 partial train loss (single batch): 23476.806641
# 	 partial train loss (single batch): 23422.423828
# 	 partial train loss (single batch): 23074.251953
# 	 partial train loss (single batch): 23013.765625
# 	 partial train loss (single batch): 22867.990234
# 	 partial train loss (single batch): 22778.052734
# 	 partial train loss (single batch): 22871.791016
# 	 partial train loss (single batch): 22559.812500
# 	 partial train loss (single batch): 22428.623047
# 	 partial train loss (single batch): 22336.578125
# 	 partial train loss (single batch): 22298.654297
# 	 partial train loss (single batch): 22245.832031
# 	 partial train loss (single batch): 22013.058594
# 	 partial train loss (single batch): 21891.158203
# 	 partial train loss (single batch): 21960.134766
# 	 partial train loss (single batch): 21742.093750
# 	 partial train loss (single batch): 21707.464844
# 	 partial train loss (single batch): 21609.566406
# 	 partial train loss (single batch): 21422.298828
# 	 partial train loss (single batch): 21130.332031
# 	 partial train loss (single batch): 21175.347656
# 	 partial train loss (single batch): 21370.289062
# 	 partial train loss (single batch): 21015.775391
# 	 partial train loss (single batch): 21117.115234
# 	 partial train loss (single batch): 21078.947266
# 	 partial train loss (single batch): 20754.242188
# 	 partial train loss (single batch): 20812.646484
# 	 partial train loss (single batch): 20621.734375
# 	 partial train loss (single batch): 20518.304688
# 	 partial train loss (single batch): 20326.517578
# 	 partial train loss (single batch): 20345.593750
# 	 partial train loss (single batch): 20368.933594
# 	 partial train loss (single batch): 20133.447266
# 	 partial train loss (single batch): 20074.058594
# 	 partial train loss (single batch): 9994.632812
#
#  EPOCH 1/50 	 train loss 142.015 	 val loss 77.596
# 	 partial train loss (single batch): 20087.828125
# 	 partial train loss (single batch): 19828.443359
# 	 partial train loss (single batch): 19791.398438
# 	 partial train loss (single batch): 19771.773438
# 	 partial train loss (single batch): 19723.857422
# 	 partial train loss (single batch): 19602.296875
# 	 partial train loss (single batch): 19704.794922
# 	 partial train loss (single batch): 19675.843750
# 	 partial train loss (single batch): 19695.785156
# 	 partial train loss (single batch): 19351.521484
# 	 partial train loss (single batch): 19246.447266
# 	 partial train loss (single batch): 19238.994141
# 	 partial train loss (single batch): 19214.386719
# 	 partial train loss (single batch): 19350.289062
# 	 partial train loss (single batch): 19035.230469
# 	 partial train loss (single batch): 18912.134766
# 	 partial train loss (single batch): 19056.351562
# 	 partial train loss (single batch): 18878.201172
# 	 partial train loss (single batch): 18929.085938
# 	 partial train loss (single batch): 18981.787109
# 	 partial train loss (single batch): 18563.667969
# 	 partial train loss (single batch): 18488.986328
# 	 partial train loss (single batch): 18716.855469
# 	 partial train loss (single batch): 18542.443359
# 	 partial train loss (single batch): 18524.859375
# 	 partial train loss (single batch): 18271.568359
# 	 partial train loss (single batch): 18474.492188
# 	 partial train loss (single batch): 18329.957031
# 	 partial train loss (single batch): 18105.625000
# 	 partial train loss (single batch): 18113.404297
# 	 partial train loss (single batch): 18019.712891
# 	 partial train loss (single batch): 18001.353516
# 	 partial train loss (single batch): 17971.640625
# 	 partial train loss (single batch): 17979.787109
# 	 partial train loss (single batch): 18076.265625
# 	 partial train loss (single batch): 17842.794922
# 	 partial train loss (single batch): 18062.529297
# 	 partial train loss (single batch): 17637.408203
# 	 partial train loss (single batch): 17627.949219
# 	 partial train loss (single batch): 17694.359375
# 	 partial train loss (single batch): 17626.841797
# 	 partial train loss (single batch): 17607.521484
# 	 partial train loss (single batch): 17472.351562
# 	 partial train loss (single batch): 17360.480469
# 	 partial train loss (single batch): 17452.248047
# 	 partial train loss (single batch): 17208.843750
# 	 partial train loss (single batch): 17298.701172
# 	 partial train loss (single batch): 17516.457031
# 	 partial train loss (single batch): 17317.101562
# 	 partial train loss (single batch): 17372.718750
# 	 partial train loss (single batch): 17305.000000
# 	 partial train loss (single batch): 17165.851562
# 	 partial train loss (single batch): 17069.873047
# 	 partial train loss (single batch): 17035.433594
# 	 partial train loss (single batch): 16994.511719
# 	 partial train loss (single batch): 17081.917969
# 	 partial train loss (single batch): 16936.308594
# 	 partial train loss (single batch): 16745.703125
# 	 partial train loss (single batch): 17159.888672
# 	 partial train loss (single batch): 16897.500000
# 	 partial train loss (single batch): 16947.923828
# 	 partial train loss (single batch): 16826.658203
# 	 partial train loss (single batch): 16792.300781
# 	 partial train loss (single batch): 16730.882812
# 	 partial train loss (single batch): 16586.072266
# 	 partial train loss (single batch): 16633.873047
# 	 partial train loss (single batch): 16424.660156
# 	 partial train loss (single batch): 16610.593750
# 	 partial train loss (single batch): 16437.105469
# 	 partial train loss (single batch): 16182.794922
# 	 partial train loss (single batch): 16480.867188
# 	 partial train loss (single batch): 16430.861328
# 	 partial train loss (single batch): 16461.935547
# 	 partial train loss (single batch): 16247.074219
# 	 partial train loss (single batch): 16348.468750
# 	 partial train loss (single batch): 16077.987305
# 	 partial train loss (single batch): 16192.235352
# 	 partial train loss (single batch): 16408.988281
# 	 partial train loss (single batch): 16033.325195
# 	 partial train loss (single batch): 16032.329102
# 	 partial train loss (single batch): 16125.400391
# 	 partial train loss (single batch): 15690.601562
# 	 partial train loss (single batch): 16207.238281
# 	 partial train loss (single batch): 15587.413086
# 	 partial train loss (single batch): 15879.021484
# 	 partial train loss (single batch): 15950.446289
# 	 partial train loss (single batch): 15819.898438
# 	 partial train loss (single batch): 15736.591797
# 	 partial train loss (single batch): 15801.363281
# 	 partial train loss (single batch): 15662.616211
# 	 partial train loss (single batch): 15661.515625
# 	 partial train loss (single batch): 15674.991211
# 	 partial train loss (single batch): 15586.883789
# 	 partial train loss (single batch): 15672.569336
# 	 partial train loss (single batch): 15922.069336
# 	 partial train loss (single batch): 15550.444336
# 	 partial train loss (single batch): 15529.093750
# 	 partial train loss (single batch): 15635.176758
# 	 partial train loss (single batch): 15424.627930
# 	 partial train loss (single batch): 15540.361328
# 	 partial train loss (single batch): 15282.619141
# 	 partial train loss (single batch): 15461.124023
# 	 partial train loss (single batch): 15496.532227
# 	 partial train loss (single batch): 15018.155273
# 	 partial train loss (single batch): 15500.202148
# 	 partial train loss (single batch): 15313.882812
# 	 partial train loss (single batch): 14914.193359
# 	 partial train loss (single batch): 15136.985352
# 	 partial train loss (single batch): 14959.193359
# 	 partial train loss (single batch): 15037.473633
# 	 partial train loss (single batch): 15192.891602
# 	 partial train loss (single batch): 14734.546875
# 	 partial train loss (single batch): 15031.302734
# 	 partial train loss (single batch): 15039.020508
# 	 partial train loss (single batch): 14988.623047
# 	 partial train loss (single batch): 15128.728516
# 	 partial train loss (single batch): 14876.198242
# 	 partial train loss (single batch): 15040.650391
# 	 partial train loss (single batch): 15020.889648
# 	 partial train loss (single batch): 14758.646484
# 	 partial train loss (single batch): 14699.464844
# 	 partial train loss (single batch): 14887.220703
# 	 partial train loss (single batch): 15020.360352
# 	 partial train loss (single batch): 14788.295898
# 	 partial train loss (single batch): 14953.683594
# 	 partial train loss (single batch): 14886.356445
# 	 partial train loss (single batch): 14887.066406
# 	 partial train loss (single batch): 14702.570312
# 	 partial train loss (single batch): 14831.603516
# 	 partial train loss (single batch): 14771.411133
# 	 partial train loss (single batch): 14868.076172
# 	 partial train loss (single batch): 14921.451172
# 	 partial train loss (single batch): 14631.528320
# 	 partial train loss (single batch): 14868.776367
# 	 partial train loss (single batch): 14618.071289
# 	 partial train loss (single batch): 14570.946289
# 	 partial train loss (single batch): 14638.064453
# 	 partial train loss (single batch): 14426.747070
# 	 partial train loss (single batch): 14470.726562
# 	 partial train loss (single batch): 14658.573242
# 	 partial train loss (single batch): 14461.173828
# 	 partial train loss (single batch): 14336.452148
# 	 partial train loss (single batch): 14293.910156
# 	 partial train loss (single batch): 14536.458008
# 	 partial train loss (single batch): 14846.238281
# 	 partial train loss (single batch): 14599.584961
# 	 partial train loss (single batch): 14071.098633
# 	 partial train loss (single batch): 14099.422852
# 	 partial train loss (single batch): 14203.339844
# 	 partial train loss (single batch): 14361.809570
# 	 partial train loss (single batch): 14082.541992
# 	 partial train loss (single batch): 13914.209961
# 	 partial train loss (single batch): 14238.266602
# 	 partial train loss (single batch): 14382.630859
# 	 partial train loss (single batch): 14481.946289
# 	 partial train loss (single batch): 14034.858398
# 	 partial train loss (single batch): 13953.041992
# 	 partial train loss (single batch): 14136.749023
# 	 partial train loss (single batch): 14146.003906
# 	 partial train loss (single batch): 14467.711914
# 	 partial train loss (single batch): 14065.254883
# 	 partial train loss (single batch): 13993.833984
# 	 partial train loss (single batch): 14023.113281
# 	 partial train loss (single batch): 14152.039062
# 	 partial train loss (single batch): 13879.107422
# 	 partial train loss (single batch): 13942.966797
# 	 partial train loss (single batch): 14017.024414
# 	 partial train loss (single batch): 14062.594727
# 	 partial train loss (single batch): 14150.073242
# 	 partial train loss (single batch): 13948.132812
# 	 partial train loss (single batch): 13875.278320
# 	 partial train loss (single batch): 13978.254883
# 	 partial train loss (single batch): 13490.301758
# 	 partial train loss (single batch): 13720.295898
# 	 partial train loss (single batch): 14035.146484
# 	 partial train loss (single batch): 13785.572266
# 	 partial train loss (single batch): 13984.613281
# 	 partial train loss (single batch): 13957.008789
# 	 partial train loss (single batch): 13838.697266
# 	 partial train loss (single batch): 13884.958008
# 	 partial train loss (single batch): 13511.114258
# 	 partial train loss (single batch): 13499.471680
# 	 partial train loss (single batch): 13582.223633
# 	 partial train loss (single batch): 13593.553711
# 	 partial train loss (single batch): 13778.719727
# 	 partial train loss (single batch): 13559.942383
# 	 partial train loss (single batch): 13441.397461
# 	 partial train loss (single batch): 6700.375977
#
#  EPOCH 2/50 	 train loss 62.550 	 val loss 53.066
# 	 partial train loss (single batch): 13645.218750
# 	 partial train loss (single batch): 13345.346680
# 	 partial train loss (single batch): 13473.195312
# 	 partial train loss (single batch): 13551.963867
# 	 partial train loss (single batch): 13441.059570
# 	 partial train loss (single batch): 13388.526367
# 	 partial train loss (single batch): 13509.983398
# 	 partial train loss (single batch): 13811.856445
# 	 partial train loss (single batch): 13777.393555
# 	 partial train loss (single batch): 13408.997070
# 	 partial train loss (single batch): 13328.210938
# 	 partial train loss (single batch): 13582.844727
# 	 partial train loss (single batch): 13701.552734
# 	 partial train loss (single batch): 13690.491211
# 	 partial train loss (single batch): 13279.266602
# 	 partial train loss (single batch): 13346.072266
# 	 partial train loss (single batch): 13521.215820
# 	 partial train loss (single batch): 13398.529297
# 	 partial train loss (single batch): 13608.996094
# 	 partial train loss (single batch): 13625.710938
# 	 partial train loss (single batch): 12920.946289
# 	 partial train loss (single batch): 13227.580078
# 	 partial train loss (single batch): 13176.160156
# 	 partial train loss (single batch): 13366.521484
# 	 partial train loss (single batch): 13232.909180
# 	 partial train loss (single batch): 13031.513672
# 	 partial train loss (single batch): 13429.963867
# 	 partial train loss (single batch): 13266.514648
# 	 partial train loss (single batch): 13012.733398
# 	 partial train loss (single batch): 13021.629883
# 	 partial train loss (single batch): 12956.571289
# 	 partial train loss (single batch): 12898.066406
# 	 partial train loss (single batch): 13109.015625
# 	 partial train loss (single batch): 13078.492188
# 	 partial train loss (single batch): 13276.569336
# 	 partial train loss (single batch): 12906.129883
# 	 partial train loss (single batch): 13310.956055
# 	 partial train loss (single batch): 12813.236328
# 	 partial train loss (single batch): 12937.114258
# 	 partial train loss (single batch): 13048.526367
# 	 partial train loss (single batch): 13002.793945
# 	 partial train loss (single batch): 12869.890625
# 	 partial train loss (single batch): 12915.576172
# 	 partial train loss (single batch): 12868.004883
# 	 partial train loss (single batch): 12961.261719
# 	 partial train loss (single batch): 12656.055664
# 	 partial train loss (single batch): 12770.460938
# 	 partial train loss (single batch): 13197.050781
# 	 partial train loss (single batch): 12865.331055
# 	 partial train loss (single batch): 12995.564453
# 	 partial train loss (single batch): 12898.497070
# 	 partial train loss (single batch): 12908.976562
# 	 partial train loss (single batch): 12636.132812
# 	 partial train loss (single batch): 12906.784180
# 	 partial train loss (single batch): 12673.141602
# 	 partial train loss (single batch): 12876.457031
# 	 partial train loss (single batch): 12813.891602
# 	 partial train loss (single batch): 12452.137695
# 	 partial train loss (single batch): 13109.209961
# 	 partial train loss (single batch): 12555.715820
# 	 partial train loss (single batch): 12920.213867
# 	 partial train loss (single batch): 12687.039062
# 	 partial train loss (single batch): 12825.985352
# 	 partial train loss (single batch): 12609.813477
# 	 partial train loss (single batch): 12707.848633
# 	 partial train loss (single batch): 12725.516602
# 	 partial train loss (single batch): 12515.502930
# 	 partial train loss (single batch): 12645.822266
# 	 partial train loss (single batch): 12395.287109
# 	 partial train loss (single batch): 12313.148438
# 	 partial train loss (single batch): 12394.160156
# 	 partial train loss (single batch): 12582.794922
# 	 partial train loss (single batch): 12648.167969
# 	 partial train loss (single batch): 12512.244141
# 	 partial train loss (single batch): 12668.691406
# 	 partial train loss (single batch): 12235.704102
# 	 partial train loss (single batch): 12457.681641
# 	 partial train loss (single batch): 12605.985352
# 	 partial train loss (single batch): 12289.480469
# 	 partial train loss (single batch): 12228.605469
# 	 partial train loss (single batch): 12453.831055
# 	 partial train loss (single batch): 12059.555664
# 	 partial train loss (single batch): 12721.195312
# 	 partial train loss (single batch): 11962.070312
# 	 partial train loss (single batch): 12232.063477
# 	 partial train loss (single batch): 12283.694336
# 	 partial train loss (single batch): 12238.467773
# 	 partial train loss (single batch): 12053.440430
# 	 partial train loss (single batch): 12277.278320
# 	 partial train loss (single batch): 12144.615234
# 	 partial train loss (single batch): 12241.125977
# 	 partial train loss (single batch): 12133.172852
# 	 partial train loss (single batch): 12208.880859
# 	 partial train loss (single batch): 12212.482422
# 	 partial train loss (single batch): 12551.886719
# 	 partial train loss (single batch): 12168.789062
# 	 partial train loss (single batch): 12260.833984
# 	 partial train loss (single batch): 12340.985352
# 	 partial train loss (single batch): 12044.716797
# 	 partial train loss (single batch): 12336.656250
# 	 partial train loss (single batch): 11892.236328
# 	 partial train loss (single batch): 12152.265625
# 	 partial train loss (single batch): 12029.130859
# 	 partial train loss (single batch): 11592.352539
# 	 partial train loss (single batch): 12331.085938
# 	 partial train loss (single batch): 11995.821289
# 	 partial train loss (single batch): 11699.562500
# 	 partial train loss (single batch): 11941.292969
# 	 partial train loss (single batch): 11711.775391
# 	 partial train loss (single batch): 11821.095703
# 	 partial train loss (single batch): 12120.931641
# 	 partial train loss (single batch): 11651.707031
# 	 partial train loss (single batch): 11904.794922
# 	 partial train loss (single batch): 11909.843750
# 	 partial train loss (single batch): 11918.027344
# 	 partial train loss (single batch): 11952.531250
# 	 partial train loss (single batch): 11699.402344
# 	 partial train loss (single batch): 11869.904297
# 	 partial train loss (single batch): 11939.056641
# 	 partial train loss (single batch): 11660.855469
# 	 partial train loss (single batch): 11754.127930
# 	 partial train loss (single batch): 11850.805664
# 	 partial train loss (single batch): 12037.052734
# 	 partial train loss (single batch): 11684.698242
# 	 partial train loss (single batch): 12008.140625
# 	 partial train loss (single batch): 11941.315430
# 	 partial train loss (single batch): 11934.546875
# 	 partial train loss (single batch): 11802.590820
# 	 partial train loss (single batch): 11938.161133
# 	 partial train loss (single batch): 11910.846680
# 	 partial train loss (single batch): 11978.468750
# 	 partial train loss (single batch): 12052.281250
# 	 partial train loss (single batch): 11786.714844
# 	 partial train loss (single batch): 11871.653320
# 	 partial train loss (single batch): 11785.954102
# 	 partial train loss (single batch): 11691.584961
# 	 partial train loss (single batch): 11810.456055
# 	 partial train loss (single batch): 11609.543945
# 	 partial train loss (single batch): 11591.284180
# 	 partial train loss (single batch): 11724.990234
# 	 partial train loss (single batch): 11548.994141
# 	 partial train loss (single batch): 11325.085938
# 	 partial train loss (single batch): 11593.369141
# 	 partial train loss (single batch): 11723.053711
# 	 partial train loss (single batch): 12062.295898
# 	 partial train loss (single batch): 11721.743164
# 	 partial train loss (single batch): 11228.036133
# 	 partial train loss (single batch): 11372.131836
# 	 partial train loss (single batch): 11586.996094
# 	 partial train loss (single batch): 11630.502930
# 	 partial train loss (single batch): 11471.948242
# 	 partial train loss (single batch): 11161.657227
# 	 partial train loss (single batch): 11451.625000
# 	 partial train loss (single batch): 11550.520508
# 	 partial train loss (single batch): 11853.333008
# 	 partial train loss (single batch): 11232.379883
# 	 partial train loss (single batch): 11214.853516
# 	 partial train loss (single batch): 11530.614258
# 	 partial train loss (single batch): 11442.535156
# 	 partial train loss (single batch): 11754.739258
# 	 partial train loss (single batch): 11473.843750
# 	 partial train loss (single batch): 11136.568359
# 	 partial train loss (single batch): 11361.562500
# 	 partial train loss (single batch): 11596.372070
# 	 partial train loss (single batch): 11195.345703
# 	 partial train loss (single batch): 11304.520508
# 	 partial train loss (single batch): 11337.892578
# 	 partial train loss (single batch): 11365.538086
# 	 partial train loss (single batch): 11482.947266
# 	 partial train loss (single batch): 11277.520508
# 	 partial train loss (single batch): 11180.461914
# 	 partial train loss (single batch): 11286.729492
# 	 partial train loss (single batch): 10966.851562
# 	 partial train loss (single batch): 11198.742188
# 	 partial train loss (single batch): 11378.175781
# 	 partial train loss (single batch): 11210.571289
# 	 partial train loss (single batch): 11247.414062
# 	 partial train loss (single batch): 11304.952148
# 	 partial train loss (single batch): 11051.168945
# 	 partial train loss (single batch): 11111.857422
# 	 partial train loss (single batch): 10915.009766
# 	 partial train loss (single batch): 10943.100586
# 	 partial train loss (single batch): 11069.986328
# 	 partial train loss (single batch): 10933.473633
# 	 partial train loss (single batch): 11241.525391
# 	 partial train loss (single batch): 10959.109375
# 	 partial train loss (single batch): 10813.719727
# 	 partial train loss (single batch): 5440.111816
#
#  EPOCH 3/50 	 train loss 47.877 	 val loss 43.125
# 	 partial train loss (single batch): 11105.404297
# 	 partial train loss (single batch): 10683.464844
# 	 partial train loss (single batch): 10690.651367
# 	 partial train loss (single batch): 11100.199219
# 	 partial train loss (single batch): 10831.934570
# 	 partial train loss (single batch): 10963.035156
# 	 partial train loss (single batch): 10851.361328
# 	 partial train loss (single batch): 11405.318359
# 	 partial train loss (single batch): 11155.891602
# 	 partial train loss (single batch): 10804.134766
# 	 partial train loss (single batch): 10821.992188
# 	 partial train loss (single batch): 11077.030273
# 	 partial train loss (single batch): 11231.160156
# 	 partial train loss (single batch): 11258.292969
# 	 partial train loss (single batch): 10808.012695
# 	 partial train loss (single batch): 10700.027344
# 	 partial train loss (single batch): 11116.948242
# 	 partial train loss (single batch): 10963.444336
# 	 partial train loss (single batch): 11260.625000
# 	 partial train loss (single batch): 11111.172852
# 	 partial train loss (single batch): 10517.723633
# 	 partial train loss (single batch): 10859.121094
# 	 partial train loss (single batch): 10653.364258
# 	 partial train loss (single batch): 11187.140625
# 	 partial train loss (single batch): 10820.145508
# 	 partial train loss (single batch): 10486.670898
# 	 partial train loss (single batch): 10980.226562
# 	 partial train loss (single batch): 10877.937500
# 	 partial train loss (single batch): 10591.179688
# 	 partial train loss (single batch): 10703.254883
# 	 partial train loss (single batch): 10837.326172
# 	 partial train loss (single batch): 10628.591797
# 	 partial train loss (single batch): 10863.770508
# 	 partial train loss (single batch): 10781.034180
# 	 partial train loss (single batch): 10997.152344
# 	 partial train loss (single batch): 10509.068359
# 	 partial train loss (single batch): 11127.369141
# 	 partial train loss (single batch): 10521.953125
# 	 partial train loss (single batch): 10549.450195
# 	 partial train loss (single batch): 10568.821289
# 	 partial train loss (single batch): 10685.259766
# 	 partial train loss (single batch): 10651.640625
# 	 partial train loss (single batch): 10673.975586
# 	 partial train loss (single batch): 10555.147461
# 	 partial train loss (single batch): 10716.916016
# 	 partial train loss (single batch): 10414.984375
# 	 partial train loss (single batch): 10334.404297
# 	 partial train loss (single batch): 10874.574219
# 	 partial train loss (single batch): 10491.426758
# 	 partial train loss (single batch): 10661.500000
# 	 partial train loss (single batch): 10587.507812
# 	 partial train loss (single batch): 10501.807617
# 	 partial train loss (single batch): 10426.129883
# 	 partial train loss (single batch): 10678.518555
# 	 partial train loss (single batch): 10321.673828
# 	 partial train loss (single batch): 10578.686523
# 	 partial train loss (single batch): 10725.646484
# 	 partial train loss (single batch): 10155.341797
# 	 partial train loss (single batch): 10726.460938
# 	 partial train loss (single batch): 10328.439453
# 	 partial train loss (single batch): 10953.892578
# 	 partial train loss (single batch): 10535.769531
# 	 partial train loss (single batch): 10596.620117
# 	 partial train loss (single batch): 10423.882812
# 	 partial train loss (single batch): 10648.712891
# 	 partial train loss (single batch): 10719.570312
# 	 partial train loss (single batch): 10282.887695
# 	 partial train loss (single batch): 10550.447266
# 	 partial train loss (single batch): 10205.869141
# 	 partial train loss (single batch): 10125.970703
# 	 partial train loss (single batch): 10365.061523
# 	 partial train loss (single batch): 10386.033203
# 	 partial train loss (single batch): 10496.023438
# 	 partial train loss (single batch): 10551.836914
# 	 partial train loss (single batch): 10570.157227
# 	 partial train loss (single batch): 10227.272461
# 	 partial train loss (single batch): 10322.722656
# 	 partial train loss (single batch): 10556.998047
# 	 partial train loss (single batch): 10235.144531
# 	 partial train loss (single batch): 10141.057617
# 	 partial train loss (single batch): 10393.128906
# 	 partial train loss (single batch): 10058.858398
# 	 partial train loss (single batch): 10592.548828
# 	 partial train loss (single batch): 9956.411133
# 	 partial train loss (single batch): 10234.514648
# 	 partial train loss (single batch): 10171.276367
# 	 partial train loss (single batch): 10353.784180
# 	 partial train loss (single batch): 9989.558594
# 	 partial train loss (single batch): 10209.166992
# 	 partial train loss (single batch): 10227.770508
# 	 partial train loss (single batch): 10293.395508
# 	 partial train loss (single batch): 10141.027344
# 	 partial train loss (single batch): 10305.877930
# 	 partial train loss (single batch): 10290.295898
# 	 partial train loss (single batch): 10441.822266
# 	 partial train loss (single batch): 10279.301758
# 	 partial train loss (single batch): 10343.295898
# 	 partial train loss (single batch): 10299.126953
# 	 partial train loss (single batch): 10177.703125
# 	 partial train loss (single batch): 10328.875000
# 	 partial train loss (single batch): 10167.402344
# 	 partial train loss (single batch): 10249.645508
# 	 partial train loss (single batch): 10043.564453
# 	 partial train loss (single batch): 9680.849609
# 	 partial train loss (single batch): 10444.476562
# 	 partial train loss (single batch): 10124.610352
# 	 partial train loss (single batch): 9876.191406
# 	 partial train loss (single batch): 10047.016602
# 	 partial train loss (single batch): 9944.297852
# 	 partial train loss (single batch): 10156.974609
# 	 partial train loss (single batch): 10298.827148
# 	 partial train loss (single batch): 9812.096680
# 	 partial train loss (single batch): 10223.403320
# 	 partial train loss (single batch): 10087.101562
# 	 partial train loss (single batch): 10217.169922
# 	 partial train loss (single batch): 10075.215820
# 	 partial train loss (single batch): 9954.785156
# 	 partial train loss (single batch): 9980.445312
# 	 partial train loss (single batch): 10165.364258
# 	 partial train loss (single batch): 9853.889648
# 	 partial train loss (single batch): 10026.482422
# 	 partial train loss (single batch): 10150.668945
# 	 partial train loss (single batch): 10255.943359
# 	 partial train loss (single batch): 9868.303711
# 	 partial train loss (single batch): 10262.640625
# 	 partial train loss (single batch): 10199.183594
# 	 partial train loss (single batch): 10101.773438
# 	 partial train loss (single batch): 10111.192383
# 	 partial train loss (single batch): 10244.835938
# 	 partial train loss (single batch): 10049.315430
# 	 partial train loss (single batch): 10278.064453
# 	 partial train loss (single batch): 10286.508789
# 	 partial train loss (single batch): 10135.459961
# 	 partial train loss (single batch): 10207.235352
# 	 partial train loss (single batch): 10102.148438
# 	 partial train loss (single batch): 10014.794922
# 	 partial train loss (single batch): 10150.845703
# 	 partial train loss (single batch): 9923.000977
# 	 partial train loss (single batch): 10020.101562
# 	 partial train loss (single batch): 10064.230469
# 	 partial train loss (single batch): 9905.611328
# 	 partial train loss (single batch): 9677.039062
# 	 partial train loss (single batch): 9979.991211
# 	 partial train loss (single batch): 10173.179688
# 	 partial train loss (single batch): 10435.508789
# 	 partial train loss (single batch): 10218.772461
# 	 partial train loss (single batch): 9678.897461
# 	 partial train loss (single batch): 9853.328125
# 	 partial train loss (single batch): 10186.417969
# 	 partial train loss (single batch): 10030.498047
# 	 partial train loss (single batch): 9867.935547
# 	 partial train loss (single batch): 9573.795898
# 	 partial train loss (single batch): 9844.054688
# 	 partial train loss (single batch): 9969.871094
# 	 partial train loss (single batch): 10199.397461
# 	 partial train loss (single batch): 9828.004883
# 	 partial train loss (single batch): 9690.703125
# 	 partial train loss (single batch): 9977.391602
# 	 partial train loss (single batch): 10125.911133
# 	 partial train loss (single batch): 10263.069336
# 	 partial train loss (single batch): 9984.906250
# 	 partial train loss (single batch): 9686.110352
# 	 partial train loss (single batch): 9937.375977
# 	 partial train loss (single batch): 10224.823242
# 	 partial train loss (single batch): 9765.203125
# 	 partial train loss (single batch): 9978.626953
# 	 partial train loss (single batch): 9932.082031
# 	 partial train loss (single batch): 9908.195312
# 	 partial train loss (single batch): 10108.749023
# 	 partial train loss (single batch): 9843.453125
# 	 partial train loss (single batch): 9782.769531
# 	 partial train loss (single batch): 9868.511719
# 	 partial train loss (single batch): 9669.444336
# 	 partial train loss (single batch): 9943.614258
# 	 partial train loss (single batch): 10037.354492
# 	 partial train loss (single batch): 9934.783203
# 	 partial train loss (single batch): 10075.378906
# 	 partial train loss (single batch): 10056.850586
# 	 partial train loss (single batch): 9655.365234
# 	 partial train loss (single batch): 9862.539062
# 	 partial train loss (single batch): 9669.693359
# 	 partial train loss (single batch): 9806.642578
# 	 partial train loss (single batch): 9858.041992
# 	 partial train loss (single batch): 9733.870117
# 	 partial train loss (single batch): 9994.111328
# 	 partial train loss (single batch): 9670.485352
# 	 partial train loss (single batch): 9552.031250
# 	 partial train loss (single batch): 4942.581055
#
#  EPOCH 4/50 	 train loss 40.310 	 val loss 38.328
# 	 partial train loss (single batch): 9818.194336
# 	 partial train loss (single batch): 9484.516602
# 	 partial train loss (single batch): 9447.517578
# 	 partial train loss (single batch): 9897.606445
# 	 partial train loss (single batch): 9624.886719
# 	 partial train loss (single batch): 9822.290039
# 	 partial train loss (single batch): 9640.530273
# 	 partial train loss (single batch): 10231.378906
# 	 partial train loss (single batch): 9905.154297
# 	 partial train loss (single batch): 9686.855469
# 	 partial train loss (single batch): 9650.707031
# 	 partial train loss (single batch): 9949.278320
# 	 partial train loss (single batch): 10108.077148
# 	 partial train loss (single batch): 10201.860352
# 	 partial train loss (single batch): 9715.751953
# 	 partial train loss (single batch): 9624.506836
# 	 partial train loss (single batch): 9979.050781
# 	 partial train loss (single batch): 9857.745117
# 	 partial train loss (single batch): 10298.608398
# 	 partial train loss (single batch): 9881.014648
# 	 partial train loss (single batch): 9425.708984
# 	 partial train loss (single batch): 9835.193359
# 	 partial train loss (single batch): 9530.048828
# 	 partial train loss (single batch): 10021.484375
# 	 partial train loss (single batch): 9751.699219
# 	 partial train loss (single batch): 9432.376953
# 	 partial train loss (single batch): 9974.480469
# 	 partial train loss (single batch): 9740.559570
# 	 partial train loss (single batch): 9653.734375
# 	 partial train loss (single batch): 9672.979492
# 	 partial train loss (single batch): 9861.676758
# 	 partial train loss (single batch): 9642.614258
# 	 partial train loss (single batch): 9906.534180
# 	 partial train loss (single batch): 9753.088867
# 	 partial train loss (single batch): 9974.396484
# 	 partial train loss (single batch): 9646.861328
# 	 partial train loss (single batch): 10146.247070
# 	 partial train loss (single batch): 9656.475586
# 	 partial train loss (single batch): 9635.890625
# 	 partial train loss (single batch): 9598.706055
# 	 partial train loss (single batch): 9670.317383
# 	 partial train loss (single batch): 9709.851562
# 	 partial train loss (single batch): 9902.851562
# 	 partial train loss (single batch): 9608.273438
# 	 partial train loss (single batch): 9800.677734
# 	 partial train loss (single batch): 9506.212891
# 	 partial train loss (single batch): 9454.824219
# 	 partial train loss (single batch): 9956.299805
# 	 partial train loss (single batch): 9557.844727
# 	 partial train loss (single batch): 9787.929688
# 	 partial train loss (single batch): 9602.919922
# 	 partial train loss (single batch): 9651.258789
# 	 partial train loss (single batch): 9628.814453
# 	 partial train loss (single batch): 9876.246094
# 	 partial train loss (single batch): 9510.601562
# 	 partial train loss (single batch): 9667.251953
# 	 partial train loss (single batch): 9897.716797
# 	 partial train loss (single batch): 9340.641602
# 	 partial train loss (single batch): 9924.493164
# 	 partial train loss (single batch): 9447.144531
# 	 partial train loss (single batch): 10098.589844
# 	 partial train loss (single batch): 9694.308594
# 	 partial train loss (single batch): 9801.574219
# 	 partial train loss (single batch): 9654.837891
# 	 partial train loss (single batch): 9845.771484
# 	 partial train loss (single batch): 9970.393555
# 	 partial train loss (single batch): 9495.993164
# 	 partial train loss (single batch): 9748.801758
# 	 partial train loss (single batch): 9499.442383
# 	 partial train loss (single batch): 9378.094727
# 	 partial train loss (single batch): 9561.030273
# 	 partial train loss (single batch): 9616.521484
# 	 partial train loss (single batch): 9745.529297
# 	 partial train loss (single batch): 9807.709961
# 	 partial train loss (single batch): 9891.556641
# 	 partial train loss (single batch): 9502.439453
# 	 partial train loss (single batch): 9556.959961
# 	 partial train loss (single batch): 9731.405273
# 	 partial train loss (single batch): 9486.856445
# 	 partial train loss (single batch): 9413.429688
# 	 partial train loss (single batch): 9647.021484
# 	 partial train loss (single batch): 9360.184570
# 	 partial train loss (single batch): 9919.148438
# 	 partial train loss (single batch): 9224.336914
# 	 partial train loss (single batch): 9530.302734
# 	 partial train loss (single batch): 9474.486328
# 	 partial train loss (single batch): 9699.574219
# 	 partial train loss (single batch): 9311.374023
# 	 partial train loss (single batch): 9529.849609
# 	 partial train loss (single batch): 9433.389648
# 	 partial train loss (single batch): 9644.390625
# 	 partial train loss (single batch): 9402.080078
# 	 partial train loss (single batch): 9622.030273
# 	 partial train loss (single batch): 9640.957031
# 	 partial train loss (single batch): 9832.300781
# 	 partial train loss (single batch): 9665.938477
# 	 partial train loss (single batch): 9751.871094
# 	 partial train loss (single batch): 9727.299805
# 	 partial train loss (single batch): 9561.368164
# 	 partial train loss (single batch): 9676.406250
# 	 partial train loss (single batch): 9389.333984
# 	 partial train loss (single batch): 9553.944336
# 	 partial train loss (single batch): 9402.672852
# 	 partial train loss (single batch): 9016.465820
# 	 partial train loss (single batch): 9769.587891
# 	 partial train loss (single batch): 9547.574219
# 	 partial train loss (single batch): 9261.185547
# 	 partial train loss (single batch): 9439.799805
# 	 partial train loss (single batch): 9429.761719
# 	 partial train loss (single batch): 9657.821289
# 	 partial train loss (single batch): 9684.728516
# 	 partial train loss (single batch): 9235.538086
# 	 partial train loss (single batch): 9624.052734
# 	 partial train loss (single batch): 9497.860352
# 	 partial train loss (single batch): 9585.146484
# 	 partial train loss (single batch): 9464.697266
# 	 partial train loss (single batch): 9441.946289
# 	 partial train loss (single batch): 9394.246094
# 	 partial train loss (single batch): 9408.541016
# 	 partial train loss (single batch): 9258.753906
# 	 partial train loss (single batch): 9442.601562
# 	 partial train loss (single batch): 9697.384766
# 	 partial train loss (single batch): 9674.806641
# 	 partial train loss (single batch): 9298.595703
# 	 partial train loss (single batch): 9716.702148
# 	 partial train loss (single batch): 9646.043945
# 	 partial train loss (single batch): 9492.599609
# 	 partial train loss (single batch): 9607.206055
# 	 partial train loss (single batch): 9822.700195
# 	 partial train loss (single batch): 9515.689453
# 	 partial train loss (single batch): 9678.789062
# 	 partial train loss (single batch): 9737.326172
# 	 partial train loss (single batch): 9540.423828
# 	 partial train loss (single batch): 9547.333984
# 	 partial train loss (single batch): 9443.986328
# 	 partial train loss (single batch): 9411.111328
# 	 partial train loss (single batch): 9574.947266
# 	 partial train loss (single batch): 9416.442383
# 	 partial train loss (single batch): 9430.209961
# 	 partial train loss (single batch): 9533.452148
# 	 partial train loss (single batch): 9356.390625
# 	 partial train loss (single batch): 9184.505859
# 	 partial train loss (single batch): 9413.381836
# 	 partial train loss (single batch): 9608.030273
# 	 partial train loss (single batch): 9840.993164
# 	 partial train loss (single batch): 9778.830078
# 	 partial train loss (single batch): 9211.717773
# 	 partial train loss (single batch): 9307.680664
# 	 partial train loss (single batch): 9760.154297
# 	 partial train loss (single batch): 9504.641602
# 	 partial train loss (single batch): 9316.621094
# 	 partial train loss (single batch): 9137.545898
# 	 partial train loss (single batch): 9379.303711
# 	 partial train loss (single batch): 9420.531250
# 	 partial train loss (single batch): 9751.902344
# 	 partial train loss (single batch): 9300.796875
# 	 partial train loss (single batch): 9227.543945
# 	 partial train loss (single batch): 9413.704102
# 	 partial train loss (single batch): 9592.644531
# 	 partial train loss (single batch): 9674.107422
# 	 partial train loss (single batch): 9402.513672
# 	 partial train loss (single batch): 9138.123047
# 	 partial train loss (single batch): 9470.141602
# 	 partial train loss (single batch): 9720.004883
# 	 partial train loss (single batch): 9221.458008
# 	 partial train loss (single batch): 9433.367188
# 	 partial train loss (single batch): 9399.556641
# 	 partial train loss (single batch): 9419.645508
# 	 partial train loss (single batch): 9592.320312
# 	 partial train loss (single batch): 9328.702148
# 	 partial train loss (single batch): 9325.138672
# 	 partial train loss (single batch): 9437.593750
# 	 partial train loss (single batch): 9148.058594
# 	 partial train loss (single batch): 9419.032227
# 	 partial train loss (single batch): 9459.814453
# 	 partial train loss (single batch): 9549.678711
# 	 partial train loss (single batch): 9486.611328
# 	 partial train loss (single batch): 9471.619141
# 	 partial train loss (single batch): 9184.811523
# 	 partial train loss (single batch): 9278.990234
# 	 partial train loss (single batch): 9136.879883
# 	 partial train loss (single batch): 9287.132812
# 	 partial train loss (single batch): 9405.982422
# 	 partial train loss (single batch): 9224.652344
# 	 partial train loss (single batch): 9596.230469
# 	 partial train loss (single batch): 9336.185547
# 	 partial train loss (single batch): 9242.658203
# 	 partial train loss (single batch): 4732.653320
#
#  EPOCH 5/50 	 train loss 37.451 	 val loss 36.924
# 	 partial train loss (single batch): 9453.755859
# 	 partial train loss (single batch): 9055.220703
# 	 partial train loss (single batch): 9045.408203
# 	 partial train loss (single batch): 9449.685547
# 	 partial train loss (single batch): 9190.763672
# 	 partial train loss (single batch): 9403.488281
# 	 partial train loss (single batch): 9231.716797
# 	 partial train loss (single batch): 9746.948242
# 	 partial train loss (single batch): 9503.787109
# 	 partial train loss (single batch): 9197.363281
# 	 partial train loss (single batch): 9280.547852
# 	 partial train loss (single batch): 9611.124023
# 	 partial train loss (single batch): 9680.268555
# 	 partial train loss (single batch): 9710.723633
# 	 partial train loss (single batch): 9355.361328
# 	 partial train loss (single batch): 9180.090820
# 	 partial train loss (single batch): 9579.111328
# 	 partial train loss (single batch): 9532.001953
# 	 partial train loss (single batch): 9905.087891
# ...
# 	 partial train loss (single batch): 7924.434570
# 	 partial train loss (single batch): 8252.932617
# 	 partial train loss (single batch): 8001.420410
# 	 partial train loss (single batch): 8201.305664
# 	 partial train loss (single batch): 8275.958984
# 	 partial train loss (single batch): 7992.907227
# 	 partial train loss (single batch): 8424.537109
# 	 partial train loss (single batch): 8040.384766
# 	 partial train loss (single batch): 8411.076172
# 	 partial train loss (single batch): 8154.815918
# 	 partial train loss (single batch): 8337.116211
# 	 partial train loss (single batch): 8043.016602
# 	 partial train loss (single batch): 8270.959961
# 	 partial train loss (single batch): 8361.391602
# 	 partial train loss (single batch): 8000.883789
# 	 partial train loss (single batch): 8220.485352
# 	 partial train loss (single batch): 8089.849609
# 	 partial train loss (single batch): 7880.393066
# 	 partial train loss (single batch): 8168.395996
# 	 partial train loss (single batch): 8085.115234
# 	 partial train loss (single batch): 8152.517090
# 	 partial train loss (single batch): 8308.447266
# 	 partial train loss (single batch): 8403.181641
# 	 partial train loss (single batch): 8132.431152
# 	 partial train loss (single batch): 8030.460938
# 	 partial train loss (single batch): 8352.160156
# 	 partial train loss (single batch): 8065.469727
# 	 partial train loss (single batch): 7906.208008
# 	 partial train loss (single batch): 8170.489258
# 	 partial train loss (single batch): 8158.831055
# 	 partial train loss (single batch): 8584.894531
# 	 partial train loss (single batch): 7828.887207
# 	 partial train loss (single batch): 8129.208008
# 	 partial train loss (single batch): 8113.810547
# 	 partial train loss (single batch): 8265.248047
# 	 partial train loss (single batch): 8011.025879
# 	 partial train loss (single batch): 8047.847656
# 	 partial train loss (single batch): 8093.471191
# 	 partial train loss (single batch): 8148.349609
# 	 partial train loss (single batch): 7995.944336
# 	 partial train loss (single batch): 8214.501953
# 	 partial train loss (single batch): 8181.009277
# 	 partial train loss (single batch): 8372.613281
# 	 partial train loss (single batch): 8185.881348
# 	 partial train loss (single batch): 8174.812988
# 	 partial train loss (single batch): 8254.664062
# 	 partial train loss (single batch): 8135.004883
# 	 partial train loss (single batch): 8371.720703
# 	 partial train loss (single batch): 8026.511230
# 	 partial train loss (single batch): 8209.984375
# 	 partial train loss (single batch): 7902.514648
# 	 partial train loss (single batch): 7695.222168
# 	 partial train loss (single batch): 8400.630859
# 	 partial train loss (single batch): 7966.047363
# 	 partial train loss (single batch): 7802.012695
# 	 partial train loss (single batch): 8150.511719
# 	 partial train loss (single batch): 8088.403320
# 	 partial train loss (single batch): 8117.653809
# 	 partial train loss (single batch): 8262.245117
# 	 partial train loss (single batch): 7726.095703
# 	 partial train loss (single batch): 8151.676758
# 	 partial train loss (single batch): 8160.481445
# 	 partial train loss (single batch): 8284.214844
# 	 partial train loss (single batch): 8211.564453
# 	 partial train loss (single batch): 8155.047852
# 	 partial train loss (single batch): 7932.576660
# 	 partial train loss (single batch): 7997.340820
# 	 partial train loss (single batch): 7940.330078
# 	 partial train loss (single batch): 8007.303711
# 	 partial train loss (single batch): 8141.754395
# 	 partial train loss (single batch): 8205.882812
# 	 partial train loss (single batch): 7841.159668
# 	 partial train loss (single batch): 8387.479492
# 	 partial train loss (single batch): 8172.118652
# 	 partial train loss (single batch): 8085.003906
# 	 partial train loss (single batch): 8241.622070
# 	 partial train loss (single batch): 8477.491211
# 	 partial train loss (single batch): 8111.194824
# 	 partial train loss (single batch): 8155.007812
# 	 partial train loss (single batch): 8320.042969
# 	 partial train loss (single batch): 8124.295898
# 	 partial train loss (single batch): 8160.415039
# 	 partial train loss (single batch): 8097.667480
# 	 partial train loss (single batch): 8040.813477
# 	 partial train loss (single batch): 8142.755859
# 	 partial train loss (single batch): 7953.968750
# 	 partial train loss (single batch): 8218.820312
# 	 partial train loss (single batch): 8104.253906
# 	 partial train loss (single batch): 8062.899414
# 	 partial train loss (single batch): 7836.319336
# 	 partial train loss (single batch): 7893.926270
# 	 partial train loss (single batch): 8136.281250
# 	 partial train loss (single batch): 8307.855469
# 	 partial train loss (single batch): 8697.712891
# 	 partial train loss (single batch): 7890.412598
# 	 partial train loss (single batch): 8001.769531
# 	 partial train loss (single batch): 8553.049805
# 	 partial train loss (single batch): 8328.285156
# 	 partial train loss (single batch): 7955.818359
# 	 partial train loss (single batch): 7708.092773
# 	 partial train loss (single batch): 8079.208496
# 	 partial train loss (single batch): 8091.368164
# 	 partial train loss (single batch): 8252.197266
# 	 partial train loss (single batch): 8073.726074
# 	 partial train loss (single batch): 7965.305664
# 	 partial train loss (single batch): 8158.501953
# 	 partial train loss (single batch): 8316.750000
# 	 partial train loss (single batch): 8447.355469
# 	 partial train loss (single batch): 8094.992676
# 	 partial train loss (single batch): 7863.865234
# 	 partial train loss (single batch): 8064.403809
# 	 partial train loss (single batch): 8327.005859
# 	 partial train loss (single batch): 7861.214844
# 	 partial train loss (single batch): 8158.231934
# 	 partial train loss (single batch): 8147.116211
# 	 partial train loss (single batch): 8292.020508
# 	 partial train loss (single batch): 8261.212891
# 	 partial train loss (single batch): 7942.293945
# 	 partial train loss (single batch): 8109.586914
# 	 partial train loss (single batch): 8032.784180
# 	 partial train loss (single batch): 7943.755371
# 	 partial train loss (single batch): 8155.175781
# 	 partial train loss (single batch): 8167.145020
# 	 partial train loss (single batch): 8304.464844
# 	 partial train loss (single batch): 8167.948242
# 	 partial train loss (single batch): 8232.066406
# 	 partial train loss (single batch): 7932.756836
# 	 partial train loss (single batch): 8181.393555
# 	 partial train loss (single batch): 7837.713379
# 	 partial train loss (single batch): 8162.863281
# 	 partial train loss (single batch): 8139.387695
# 	 partial train loss (single batch): 8011.218750
# 	 partial train loss (single batch): 8136.026367
# 	 partial train loss (single batch): 8155.300781
# 	 partial train loss (single batch): 8085.011719
# 	 partial train loss (single batch): 4037.983398
#
#  EPOCH 49/50 	 train loss 31.776 	 val loss 32.278
# 	 partial train loss (single batch): 8133.776855
# 	 partial train loss (single batch): 7863.906250
# 	 partial train loss (single batch): 7893.488281
# 	 partial train loss (single batch): 8215.490234
# 	 partial train loss (single batch): 7917.974609
# 	 partial train loss (single batch): 8167.355469
# 	 partial train loss (single batch): 7844.399414
# 	 partial train loss (single batch): 8423.325195
# 	 partial train loss (single batch): 8172.386230
# 	 partial train loss (single batch): 7976.574219
# 	 partial train loss (single batch): 8047.040527
# 	 partial train loss (single batch): 8304.687500
# 	 partial train loss (single batch): 8329.591797
# 	 partial train loss (single batch): 8423.568359
# 	 partial train loss (single batch): 8115.322266
# 	 partial train loss (single batch): 7895.274414
# 	 partial train loss (single batch): 8473.307617
# 	 partial train loss (single batch): 8339.184570
# 	 partial train loss (single batch): 8581.736328
# 	 partial train loss (single batch): 8126.946289
# 	 partial train loss (single batch): 7853.591309
# 	 partial train loss (single batch): 8516.606445
# 	 partial train loss (single batch): 7661.394531
# 	 partial train loss (single batch): 8249.183594
# 	 partial train loss (single batch): 8312.710938
# 	 partial train loss (single batch): 8039.254395
# 	 partial train loss (single batch): 8494.050781
# 	 partial train loss (single batch): 8233.439453
# 	 partial train loss (single batch): 8074.155273
# 	 partial train loss (single batch): 8012.490234
# 	 partial train loss (single batch): 8225.695312
# 	 partial train loss (single batch): 8055.648438
# 	 partial train loss (single batch): 8308.124023
# 	 partial train loss (single batch): 8229.769531
# 	 partial train loss (single batch): 8324.273438
# 	 partial train loss (single batch): 8088.396973
# 	 partial train loss (single batch): 8362.224609
# 	 partial train loss (single batch): 8080.627441
# 	 partial train loss (single batch): 8211.273438
# 	 partial train loss (single batch): 8063.284180
# 	 partial train loss (single batch): 8147.848633
# 	 partial train loss (single batch): 8172.280273
# 	 partial train loss (single batch): 8215.628906
# 	 partial train loss (single batch): 8127.625488
# 	 partial train loss (single batch): 8292.170898
# 	 partial train loss (single batch): 7929.589355
# 	 partial train loss (single batch): 7739.506836
# 	 partial train loss (single batch): 8297.659180
# 	 partial train loss (single batch): 7890.464844
# 	 partial train loss (single batch): 8093.909180
# 	 partial train loss (single batch): 8358.273438
# 	 partial train loss (single batch): 8038.153320
# 	 partial train loss (single batch): 8003.139160
# 	 partial train loss (single batch): 8280.833984
# 	 partial train loss (single batch): 7955.611328
# 	 partial train loss (single batch): 8151.464355
# 	 partial train loss (single batch): 8331.588867
# 	 partial train loss (single batch): 7970.715820
# 	 partial train loss (single batch): 8425.182617
# 	 partial train loss (single batch): 8033.957031
# 	 partial train loss (single batch): 8432.521484
# 	 partial train loss (single batch): 8186.299805
# 	 partial train loss (single batch): 8300.403320
# 	 partial train loss (single batch): 7972.346680
# 	 partial train loss (single batch): 8206.276367
# 	 partial train loss (single batch): 8363.845703
# 	 partial train loss (single batch): 8025.957031
# 	 partial train loss (single batch): 8205.603516
# 	 partial train loss (single batch): 8031.653809
# 	 partial train loss (single batch): 7870.469727
# 	 partial train loss (single batch): 8047.080078
# 	 partial train loss (single batch): 8082.254395
# 	 partial train loss (single batch): 8153.707031
# 	 partial train loss (single batch): 8399.641602
# 	 partial train loss (single batch): 8428.503906
# 	 partial train loss (single batch): 8088.427734
# 	 partial train loss (single batch): 7998.317383
# 	 partial train loss (single batch): 8295.899414
# 	 partial train loss (single batch): 8091.874512
# 	 partial train loss (single batch): 7924.985840
# 	 partial train loss (single batch): 8129.409180
# 	 partial train loss (single batch): 8120.565918
# 	 partial train loss (single batch): 8633.585938
# 	 partial train loss (single batch): 7737.688477
# 	 partial train loss (single batch): 8151.441406
# 	 partial train loss (single batch): 8049.046875
# 	 partial train loss (single batch): 8227.306641
# 	 partial train loss (single batch): 7916.830566
# 	 partial train loss (single batch): 8037.633301
# 	 partial train loss (single batch): 8124.967285
# 	 partial train loss (single batch): 8105.007324
# 	 partial train loss (single batch): 8001.096191
# 	 partial train loss (single batch): 8274.725586
# 	 partial train loss (single batch): 8117.872559
# 	 partial train loss (single batch): 8371.810547
# 	 partial train loss (single batch): 8168.447266
# 	 partial train loss (single batch): 8104.458984
# 	 partial train loss (single batch): 8252.759766
# 	 partial train loss (single batch): 8093.775879
# 	 partial train loss (single batch): 8403.190430
# 	 partial train loss (single batch): 8112.965332
# 	 partial train loss (single batch): 8197.825195
# 	 partial train loss (single batch): 7974.223633
# 	 partial train loss (single batch): 7702.889648
# 	 partial train loss (single batch): 8377.618164
# 	 partial train loss (single batch): 8070.045410
# 	 partial train loss (single batch): 7899.691895
# 	 partial train loss (single batch): 8158.488770
# 	 partial train loss (single batch): 8056.221680
# 	 partial train loss (single batch): 8184.880371
# 	 partial train loss (single batch): 8287.451172
# 	 partial train loss (single batch): 7772.283691
# 	 partial train loss (single batch): 8158.801758
# 	 partial train loss (single batch): 8185.592773
# 	 partial train loss (single batch): 8251.716797
# 	 partial train loss (single batch): 8213.666016
# 	 partial train loss (single batch): 8137.717285
# 	 partial train loss (single batch): 7983.186523
# 	 partial train loss (single batch): 7962.953125
# 	 partial train loss (single batch): 7888.679199
# 	 partial train loss (single batch): 7943.393555
# 	 partial train loss (single batch): 8152.825195
# 	 partial train loss (single batch): 8194.888672
# 	 partial train loss (single batch): 7859.038574
# 	 partial train loss (single batch): 8347.142578
# 	 partial train loss (single batch): 8176.974121
# 	 partial train loss (single batch): 8063.860840
# 	 partial train loss (single batch): 8208.323242
# 	 partial train loss (single batch): 8381.457031
# 	 partial train loss (single batch): 8108.551758
# 	 partial train loss (single batch): 8243.006836
# 	 partial train loss (single batch): 8260.620117
# 	 partial train loss (single batch): 8169.581055
# 	 partial train loss (single batch): 8156.665527
# 	 partial train loss (single batch): 8055.966797
# 	 partial train loss (single batch): 8100.803223
# 	 partial train loss (single batch): 8168.669922
# 	 partial train loss (single batch): 7920.395508
# 	 partial train loss (single batch): 8190.322266
# 	 partial train loss (single batch): 8096.498535
# 	 partial train loss (single batch): 8073.426270
# 	 partial train loss (single batch): 7874.652344
# 	 partial train loss (single batch): 7972.992188
# 	 partial train loss (single batch): 8187.203125
# 	 partial train loss (single batch): 8302.322266
# 	 partial train loss (single batch): 8683.751953
# 	 partial train loss (single batch): 8020.406250
# 	 partial train loss (single batch): 7990.011719
# 	 partial train loss (single batch): 8555.832031
# 	 partial train loss (single batch): 8238.560547
# 	 partial train loss (single batch): 7933.652344
# 	 partial train loss (single batch): 7808.868652
# 	 partial train loss (single batch): 8055.562500
# 	 partial train loss (single batch): 8095.209473
# 	 partial train loss (single batch): 8255.207031
# 	 partial train loss (single batch): 8062.195801
# 	 partial train loss (single batch): 8013.250000
# 	 partial train loss (single batch): 8217.152344
# 	 partial train loss (single batch): 8315.707031
# 	 partial train loss (single batch): 8399.049805
# 	 partial train loss (single batch): 8121.858887
# 	 partial train loss (single batch): 7829.222168
# 	 partial train loss (single batch): 8075.877930
# 	 partial train loss (single batch): 8278.756836
# 	 partial train loss (single batch): 7907.705078
# 	 partial train loss (single batch): 8133.005859
# 	 partial train loss (single batch): 8143.020020
# 	 partial train loss (single batch): 8208.890625
# 	 partial train loss (single batch): 8293.313477
# 	 partial train loss (single batch): 7960.333496
# 	 partial train loss (single batch): 8189.988281
# 	 partial train loss (single batch): 7979.869141
# 	 partial train loss (single batch): 7960.860352
# 	 partial train loss (single batch): 8105.664062
# 	 partial train loss (single batch): 8203.874023
# 	 partial train loss (single batch): 8246.057617
# 	 partial train loss (single batch): 8148.249023
# 	 partial train loss (single batch): 8204.017578
# 	 partial train loss (single batch): 7912.047852
# 	 partial train loss (single batch): 8131.223633
# 	 partial train loss (single batch): 7811.688477
# 	 partial train loss (single batch): 8171.683105
# 	 partial train loss (single batch): 8019.884277
# 	 partial train loss (single batch): 8012.146484
# 	 partial train loss (single batch): 8205.726562
# 	 partial train loss (single batch): 8121.519043
# 	 partial train loss (single batch): 8147.182617
# 	 partial train loss (single batch): 4056.658203
#
#  EPOCH 50/50 	 train loss 31.776 	 val loss 32.311

# %%
def show_image(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


vae.eval()

with torch.no_grad():

    # sample latent vectors from the normal distribution
    latent = torch.randn(128, d, device=device)

    # reconstruct images from the latent vectors
    img_recon = vae.decoder(latent)
    img_recon = img_recon.cpu()

    fig, ax = plt.subplots(figsize=(20, 8.5))
    show_image(torchvision.utils.make_grid(img_recon.data[:100],10,5))
    plt.show()
