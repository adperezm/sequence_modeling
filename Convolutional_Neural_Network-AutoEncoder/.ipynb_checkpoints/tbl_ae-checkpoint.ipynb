# %%
#Example from https://medium.com/dataseries/convolutional-autoencoder-in-pytorch-on-mnist-dataset-d65145c132ac

import matplotlib.pyplot as plt # plotting library
import numpy as np # this module is useful to work with numerical arrays
import pandas as pd 
import random 
import torch
#import torchvision
#from torchvision import transforms
from torch.utils.data import Dataset, DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
import h5py

import sys

torch.cuda.empty_cache()

# %%
class TBL_Dataset(Dataset):
    """Turbulent boundary layer dataset."""

    def __init__(self, filename, transform=None, all_comps=False, norm=True):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """

        f = h5py.File(filename, "r")

        # Read attributes
        #print('Attributes:')
        #print(list(f.attrs))
        self.dstar = f.attrs['dstar']
        self.nplanes = int(f.attrs['nplanes'])
        self.nx = int(f.attrs['nx'])
        self.ny = int(f.attrs['ny'])
        self.nz = int(f.attrs['nz'])
        self.re = f.attrs['re']
        self.xl = f.attrs['xl']
        self.zl = f.attrs['zl']

        
        self.all_comps = all_comps
        
        self.norm = norm

        
        # Read data sets
        uzy = f['u']
        self.u = np.transpose(uzy, (1, 0, 2))
        vzy = f['v']
        self.v = np.transpose(vzy, (1, 0, 2))
        wzy = f['w']
        self.w = np.transpose(wzy, (1, 0, 2))
        self.y = np.copy(f['y'])
        self.z = np.copy(f['z'])
        #t = f['t']
        
        if norm == True:
            
            umax=np.amax(self.u,axis=2).reshape(self.u.shape[0],self.u.shape[0],1)
            umin=np.amin(self.u,axis=2).reshape(self.u.shape[0],self.u.shape[0],1)
            
            self.u = np.divide((self.u-umin),(umax-umin))
            
            self.umax=umax
            self.umin=umin
            
            
            if all_comps==True:
            
                vmax=np.amax(self.v,axis=2).reshape(self.v.shape[0],self.v.shape[0],1)
                vmin=np.amin(self.v,axis=2).reshape(self.v.shape[0],self.v.shape[0],1)

                wmax=np.amax(self.w,axis=2).reshape(self.w.shape[0],self.w.shape[0],1)
                wmin=np.amin(self.w,axis=2).reshape(self.w.shape[0],self.w.shape[0],1)

                self.v = np.divide((self.v-vmin),(vmax-vmin))
                self.w = np.divide((self.w-wmin),(wmax-wmin))
            
                self.vmax=vmax
                self.vmin=vmin

                self.wmax=wmax
                self.wmin=wmin

                
        f.close()
        
        self.transform = transform

    def __len__(self):
        return self.u.shape[2]

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        if self.all_comps == False:
            field = np.zeros((self.u.shape[0],self.u.shape[1],1))
            field[:,:,0] = self.u[:,:,idx].reshape(self.u.shape[0],self.u.shape[1],1)[:,:,0]
        else:
            field = np.zeros((self.u.shape[0],self.u.shape[1],3))
            field[:,:,0] = self.u[:,:,idx].reshape(self.u.shape[0],self.u.shape[1],1)[:,:,0]
            field[:,:,1] = self.v[:,:,idx].reshape(self.v.shape[0],self.u.shape[1],1)[:,:,0]
            field[:,:,2] = self.w[:,:,idx].reshape(self.w.shape[0],self.u.shape[1],1)[:,:,0]
        
        
        sample = field

        if self.transform:
            sample = self.transform(sample)

        return sample
    
class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        
        field = sample

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C x H x W
        field = field.transpose((2, 0, 1))
        return torch.from_numpy(field)

# %%
data_dir = './../subsampled_TBL_data.hdf5'
all_comps = True

train_dataset = TBL_Dataset(data_dir,transform = ToTensor(),all_comps= all_comps)
m=len(train_dataset)

# %%
[yy,zz] = np.meshgrid(train_dataset.y,train_dataset.z)
def show_image(img, all_comps):
    
    cmapp='RdBu_r'
    npimg = img.numpy()

    if all_comps==False:
        fig, ax = plt.subplots(1, 1,figsize=(10, 5), dpi=150)
        c1=ax.contourf(zz,yy,np.transpose(npimg, (1, 2, 0))[:,:,0].T,levels=100,cmap=cmapp)
        #c2=ax[1].contourf(zz,yy,np.transpose(npimg, (1, 2, 0))[:,:,1].T,levels=100,cmap=cmapp)
        #c3=ax[2].contourf(zz,yy,np.transpose(npimg, (1, 2, 0))[:,:,2].T,levels=100,cmap=cmapp)
        fig.colorbar(c1, ax=ax)
        plt.show()

        #fig, ax = plt.subplots(1, 1,figsize=(20, 10), dpi=150)
        plt.imshow(np.transpose(npimg, (1, 2, 0)))
        plt.show()
        
    else:
        fig, ax = plt.subplots(1, 3,figsize=(15, 5), dpi=150)
        c1=ax[0].contourf(zz,yy,np.transpose(npimg, (1, 2, 0))[:,:,0].T,levels=100,cmap=cmapp)
        c2=ax[1].contourf(zz,yy,np.transpose(npimg, (1, 2, 0))[:,:,1].T,levels=100,cmap=cmapp)
        c3=ax[2].contourf(zz,yy,np.transpose(npimg, (1, 2, 0))[:,:,2].T,levels=100,cmap=cmapp)
        fig.colorbar(c1, ax=ax[0])
        fig.colorbar(c2, ax=ax[1])
        fig.colorbar(c3, ax=ax[2])

        plt.show()

        #fig, ax = plt.subplots(1, 1,figsize=(20, 10), dpi=150)
        plt.imshow(np.transpose(npimg, (1, 2, 0)))
        plt.show()
        

show_image(train_dataset[0],all_comps)

# %%
train_data, val_data, test_data = random_split(train_dataset, [int(m*0.5), int(m*0.3), int(m*0.2)])
print(train_data[0].shape)
# Out:
# torch.Size([3, 64, 64])

# %%
batch_size=100

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size,shuffle=True)

i=0
for plane_batch in train_loader:
    i=i+1
    if i==2:
        break
print(plane_batch.size())
# Out:
# torch.Size([100, 3, 64, 64])

# %%
class Encoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()
        
        ### Convolutional section
        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(3, 8, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.Conv2d(8, 16, 3, stride=1, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.Conv2d(16, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            #nn.ReLU(True),
            #nn.Conv2d(16, 32, 3, stride=1, padding=1),
            nn.ReLU(True)
        )
        
        ### Flatten layer
        self.flatten = nn.Flatten(start_dim=1)
### Linear section
        self.encoder_lin = nn.Sequential(
            nn.Linear(16*32*32, 2048),
            nn.ReLU(True),
            nn.Linear(2048, encoded_space_dim)
        )
        
    def forward(self, x):
        x = self.encoder_cnn(x)
        #print(x.shape)
        x = self.flatten(x)
        #print(x.shape)
        x = self.encoder_lin(x)
        #print("===")
        #print(x.shape)
        
        return x
class Decoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()
        self.decoder_lin = nn.Sequential(
            nn.Linear(encoded_space_dim, 2048),
            nn.ReLU(True),
            nn.Linear(2048, 16*32*32),
            nn.ReLU(True)
        )
        
        self.unflatten = nn.Unflatten(dim=1, 
        unflattened_size=(16, 32, 32))

        self.decoder_conv = nn.Sequential(
            #nn.ConvTranspose2d(32, 16, 3, 
            #stride=1,padding=1, output_padding=0),
            #nn.BatchNorm2d(16),
            #nn.ReLU(True),
            nn.ConvTranspose2d(16, 16, 3, 
            stride=2,padding=1, output_padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.ConvTranspose2d(16, 8, 3, stride=1, 
            padding=1, output_padding=0),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            nn.ConvTranspose2d(8, 3, 3, stride=1, 
            padding=1, output_padding=0)
        )
        
    def forward(self, x):
        x = self.decoder_lin(x)
        #print(x.shape)
        x = self.unflatten(x) 
        #print(x.shape)
        x = self.decoder_conv(x)
        #print("===")
        #print(x.shape)
        x = torch.sigmoid(x)
        #x = self.Lrelu(x)
        
        return x

# %%
#enc=Encoder(8,128)
#dec=Decoder(8,128)
#print(plane_batch.type('torch.FloatTensor').shape)
#print("===")
#x=enc(plane_batch.type('torch.FloatTensor'))
#print("===")
#x=dec(x)

# %%
### Define the loss function
loss_fn = torch.nn.MSELoss()

### Define an optimizer (both for the encoder and the decoder!)
lr= 0.001

### Set the random seed for reproducible results
torch.manual_seed(0)

### Initialize the two networks
d = 1024

#model = Autoencoder(encoded_space_dim=encoded_space_dim)
encoder = Encoder(encoded_space_dim=d,fc2_input_dim=128)
decoder = Decoder(encoded_space_dim=d,fc2_input_dim=128)
params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-05)

# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

# Move both the encoder and the decoder to the selected device
encoder.to(device)
decoder.to(device)
# Out:
# Selected device: cpu
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=1024, out_features=2048, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=2048, out_features=16384, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(16, 32, 32))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(8, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
### Training function
def train_epoch(encoder, decoder, device, dataloader, loss_fn, optimizer):
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for image_batch in dataloader: # with "_" we just ignore the labels (the second element of the dataloader tuple)
        # Move tensor to the proper device
        image_batch = (image_batch.type('torch.FloatTensor')).to(device)
        # Encode data
        encoded_data = encoder(image_batch)
        # Decode data
        decoded_data = decoder(encoded_data)
        # Evaluate loss
        loss = loss_fn(decoded_data, image_batch)
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        print('\t partial train loss (single batch): %f' % (loss.data))
        train_loss.append(loss.detach().cpu().numpy())

    return np.mean(train_loss)

# %%
### Testing function
def test_epoch(encoder, decoder, device, dataloader, loss_fn):
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    with torch.no_grad(): # No need to track the gradients
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        for image_batch in dataloader:
            # Move tensor to the proper device
            image_batch = (image_batch.type('torch.FloatTensor')).to(device)
            # Encode data
            encoded_data = encoder(image_batch)
            # Decode data
            decoded_data = decoder(encoded_data)
            # Append the network output and the original image to the lists
            conc_out.append(decoded_data.cpu())
            conc_label.append(image_batch.cpu())
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label) 
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
def plot_ae_outputs(encoder,decoder,n=10):
    plt.figure(figsize=(16,4.5))
    targets = test_dataset.targets.numpy()
    t_idx = {i:np.where(targets==i)[0][0] for i in range(n)}
    for i in range(n):
      ax = plt.subplot(2,n,i+1)
      img = test_dataset[t_idx[i]][0].unsqueeze(0).to(device)
      encoder.eval()
      decoder.eval()
      with torch.no_grad():
         rec_img  = decoder(encoder(img))
      plt.imshow(img.cpu().squeeze().numpy(), cmap='gist_gray')
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)  
      if i == n//2:
        ax.set_title('Original images')
      ax = plt.subplot(2, n, i + 1 + n)
      plt.imshow(rec_img.cpu().squeeze().numpy(), cmap='gist_gray')  
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)  
      if i == n//2:
         ax.set_title('Reconstructed images')
    plt.show()

# %%
num_epochs = 10
diz_loss = {'train_loss':[],'val_loss':[]}
for epoch in range(num_epochs):
   train_loss =train_epoch(encoder,decoder,device,
   train_loader,loss_fn,optim)
   val_loss = test_epoch(encoder,decoder,device,test_loader,loss_fn)
   print('\n EPOCH {}/{} \t train loss {} \t val loss {}'.format(epoch + 1, num_epochs,train_loss,val_loss))
   diz_loss['train_loss'].append(train_loss)
   diz_loss['val_loss'].append(val_loss)
   #plot_ae_outputs(encoder,decoder,n=10)
# Out:
# 	 partial train loss (single batch): 0.038374
# 	 partial train loss (single batch): 0.031215
# 	 partial train loss (single batch): 0.026297
# 	 partial train loss (single batch): 0.022757
# 	 partial train loss (single batch): 0.020811
# 	 partial train loss (single batch): 0.019376
# 	 partial train loss (single batch): 0.018337
# 	 partial train loss (single batch): 0.017490
# 	 partial train loss (single batch): 0.016870
# 	 partial train loss (single batch): 0.016370
# 	 partial train loss (single batch): 0.015882
# 	 partial train loss (single batch): 0.015604
# 	 partial train loss (single batch): 0.015261
# 	 partial train loss (single batch): 0.015007
# 	 partial train loss (single batch): 0.015255
# 	 partial train loss (single batch): 0.015444
# 	 partial train loss (single batch): 0.014604
# 	 partial train loss (single batch): 0.014713
# 	 partial train loss (single batch): 0.014586
# 	 partial train loss (single batch): 0.014286
# 	 partial train loss (single batch): 0.014613
# 	 partial train loss (single batch): 0.014502
# 	 partial train loss (single batch): 0.014613
# 	 partial train loss (single batch): 0.014451
# 	 partial train loss (single batch): 0.014381
# 	 partial train loss (single batch): 0.014159
# 	 partial train loss (single batch): 0.013961
# 	 partial train loss (single batch): 0.014106
# 	 partial train loss (single batch): 0.013729
# 	 partial train loss (single batch): 0.013803
# 	 partial train loss (single batch): 0.014035
# 	 partial train loss (single batch): 0.013607
# 	 partial train loss (single batch): 0.013553
# 	 partial train loss (single batch): 0.013864
# 	 partial train loss (single batch): 0.013544
# 	 partial train loss (single batch): 0.013501
# 	 partial train loss (single batch): 0.013841
# 	 partial train loss (single batch): 0.013495
# 	 partial train loss (single batch): 0.013951
# 	 partial train loss (single batch): 0.014214
# 	 partial train loss (single batch): 0.013563
# 	 partial train loss (single batch): 0.013928
# 	 partial train loss (single batch): 0.013044
# 	 partial train loss (single batch): 0.013404
# 	 partial train loss (single batch): 0.013272
# 	 partial train loss (single batch): 0.013071
# 	 partial train loss (single batch): 0.013163
# 	 partial train loss (single batch): 0.013327
# 	 partial train loss (single batch): 0.014068
# 	 partial train loss (single batch): 0.013456
# 	 partial train loss (single batch): 0.012984
# 	 partial train loss (single batch): 0.013673
# 	 partial train loss (single batch): 0.013158
# 	 partial train loss (single batch): 0.013201
# 	 partial train loss (single batch): 0.013454
# 	 partial train loss (single batch): 0.013478
# 	 partial train loss (single batch): 0.013048
# 	 partial train loss (single batch): 0.012873
# 	 partial train loss (single batch): 0.013634
# 	 partial train loss (single batch): 0.013143
# 	 partial train loss (single batch): 0.013530
# 	 partial train loss (single batch): 0.013622
# 	 partial train loss (single batch): 0.013473
# 	 partial train loss (single batch): 0.013669
# 	 partial train loss (single batch): 0.013579
# 	 partial train loss (single batch): 0.013136
# 	 partial train loss (single batch): 0.013101
# 	 partial train loss (single batch): 0.013343
# 	 partial train loss (single batch): 0.013002
# 	 partial train loss (single batch): 0.012774
# 	 partial train loss (single batch): 0.013519
# 	 partial train loss (single batch): 0.012912
# 	 partial train loss (single batch): 0.013417
# 	 partial train loss (single batch): 0.013378
# 	 partial train loss (single batch): 0.013195
# 	 partial train loss (single batch): 0.013899
# 	 partial train loss (single batch): 0.012852
# 	 partial train loss (single batch): 0.012995
# 	 partial train loss (single batch): 0.012905
# 	 partial train loss (single batch): 0.013297
# 	 partial train loss (single batch): 0.013204
# 	 partial train loss (single batch): 0.013232
# 	 partial train loss (single batch): 0.013252
# 	 partial train loss (single batch): 0.014082
# 	 partial train loss (single batch): 0.013144
# 	 partial train loss (single batch): 0.013150
# 	 partial train loss (single batch): 0.013270
# 	 partial train loss (single batch): 0.013171
# 	 partial train loss (single batch): 0.012992
# 	 partial train loss (single batch): 0.013449
# 	 partial train loss (single batch): 0.013746
# 	 partial train loss (single batch): 0.013036
# 	 partial train loss (single batch): 0.012955
# 	 partial train loss (single batch): 0.013071
# 	 partial train loss (single batch): 0.013166
# 	 partial train loss (single batch): 0.013258
# 	 partial train loss (single batch): 0.013357
# 	 partial train loss (single batch): 0.012877
# 	 partial train loss (single batch): 0.013018
# 	 partial train loss (single batch): 0.012869
# 	 partial train loss (single batch): 0.013078
# 	 partial train loss (single batch): 0.013204
# 	 partial train loss (single batch): 0.013267
# 	 partial train loss (single batch): 0.013083
# 	 partial train loss (single batch): 0.013055
# 	 partial train loss (single batch): 0.013156
# 	 partial train loss (single batch): 0.013141
# 	 partial train loss (single batch): 0.013211
# 	 partial train loss (single batch): 0.013087
# 	 partial train loss (single batch): 0.013124
# 	 partial train loss (single batch): 0.012603
# 	 partial train loss (single batch): 0.013462
# 	 partial train loss (single batch): 0.012957
# 	 partial train loss (single batch): 0.013149
# 	 partial train loss (single batch): 0.012265
#
#  EPOCH 1/10 	 train loss 0.014357739128172398 	 val loss 0.01944352127611637
# 	 partial train loss (single batch): 0.013146
# 	 partial train loss (single batch): 0.012738
# 	 partial train loss (single batch): 0.012861
# 	 partial train loss (single batch): 0.013172
# 	 partial train loss (single batch): 0.012992
# 	 partial train loss (single batch): 0.012872
# 	 partial train loss (single batch): 0.012973
# 	 partial train loss (single batch): 0.013004
# 	 partial train loss (single batch): 0.013060
# 	 partial train loss (single batch): 0.013086
# 	 partial train loss (single batch): 0.013046
# 	 partial train loss (single batch): 0.013037
# 	 partial train loss (single batch): 0.012940
# 	 partial train loss (single batch): 0.012885
# 	 partial train loss (single batch): 0.013306
# 	 partial train loss (single batch): 0.013599
# 	 partial train loss (single batch): 0.012863
# 	 partial train loss (single batch): 0.013044
# 	 partial train loss (single batch): 0.013066
# 	 partial train loss (single batch): 0.012746
# 	 partial train loss (single batch): 0.013086
# 	 partial train loss (single batch): 0.013087
# 	 partial train loss (single batch): 0.013266
# 	 partial train loss (single batch): 0.013074
# 	 partial train loss (single batch): 0.013064
# 	 partial train loss (single batch): 0.012912
# 	 partial train loss (single batch): 0.012816
# 	 partial train loss (single batch): 0.012994
# 	 partial train loss (single batch): 0.012692
# 	 partial train loss (single batch): 0.012817
# 	 partial train loss (single batch): 0.013039
# 	 partial train loss (single batch): 0.012741
# 	 partial train loss (single batch): 0.012726
# 	 partial train loss (single batch): 0.013047
# 	 partial train loss (single batch): 0.012801
# 	 partial train loss (single batch): 0.012800
# 	 partial train loss (single batch): 0.013149
# 	 partial train loss (single batch): 0.012827
# 	 partial train loss (single batch): 0.013297
# 	 partial train loss (single batch): 0.013595
# 	 partial train loss (single batch): 0.012933
# 	 partial train loss (single batch): 0.013335
# 	 partial train loss (single batch): 0.012457
# 	 partial train loss (single batch): 0.012826
# 	 partial train loss (single batch): 0.012705
# 	 partial train loss (single batch): 0.012502
# 	 partial train loss (single batch): 0.012647
# 	 partial train loss (single batch): 0.012810
# 	 partial train loss (single batch): 0.013602
# 	 partial train loss (single batch): 0.012957
# 	 partial train loss (single batch): 0.012498
# 	 partial train loss (single batch): 0.013256
# 	 partial train loss (single batch): 0.012714
# 	 partial train loss (single batch): 0.012761
# 	 partial train loss (single batch): 0.013031
# 	 partial train loss (single batch): 0.013066
# 	 partial train loss (single batch): 0.012627
# 	 partial train loss (single batch): 0.012473
# 	 partial train loss (single batch): 0.013234
# 	 partial train loss (single batch): 0.012789
# 	 partial train loss (single batch): 0.013144
# 	 partial train loss (single batch): 0.013247
# 	 partial train loss (single batch): 0.013116
# 	 partial train loss (single batch): 0.013283
# 	 partial train loss (single batch): 0.013233
# 	 partial train loss (single batch): 0.012820
# 	 partial train loss (single batch): 0.012763
# 	 partial train loss (single batch): 0.013028
# 	 partial train loss (single batch): 0.012680
# 	 partial train loss (single batch): 0.012474
# 	 partial train loss (single batch): 0.013214
# 	 partial train loss (single batch): 0.012625
# 	 partial train loss (single batch): 0.013117
# 	 partial train loss (single batch): 0.013081
# 	 partial train loss (single batch): 0.012914
# 	 partial train loss (single batch): 0.013620
# 	 partial train loss (single batch): 0.012556
# 	 partial train loss (single batch): 0.012708
# 	 partial train loss (single batch): 0.012632
# 	 partial train loss (single batch): 0.013027
# 	 partial train loss (single batch): 0.012940
# 	 partial train loss (single batch): 0.012978
# 	 partial train loss (single batch): 0.012988
# 	 partial train loss (single batch): 0.013822
# 	 partial train loss (single batch): 0.012904
# 	 partial train loss (single batch): 0.012898
# 	 partial train loss (single batch): 0.013032
# 	 partial train loss (single batch): 0.012946
# 	 partial train loss (single batch): 0.012757
# 	 partial train loss (single batch): 0.013226
# 	 partial train loss (single batch): 0.013537
# 	 partial train loss (single batch): 0.012809
# 	 partial train loss (single batch): 0.012724
# 	 partial train loss (single batch): 0.012846
# 	 partial train loss (single batch): 0.012958
# 	 partial train loss (single batch): 0.013051
# 	 partial train loss (single batch): 0.013137
# 	 partial train loss (single batch): 0.012661
# 	 partial train loss (single batch): 0.012805
# 	 partial train loss (single batch): 0.012671
# 	 partial train loss (single batch): 0.012874
# 	 partial train loss (single batch): 0.013016
# 	 partial train loss (single batch): 0.013075
# 	 partial train loss (single batch): 0.012891
# 	 partial train loss (single batch): 0.012858
# 	 partial train loss (single batch): 0.012963
# 	 partial train loss (single batch): 0.012944
# 	 partial train loss (single batch): 0.013017
# 	 partial train loss (single batch): 0.012885
# 	 partial train loss (single batch): 0.012933
# 	 partial train loss (single batch): 0.012409
# 	 partial train loss (single batch): 0.013269
# 	 partial train loss (single batch): 0.012763
# 	 partial train loss (single batch): 0.012957
# 	 partial train loss (single batch): 0.012099
#
#  EPOCH 2/10 	 train loss 0.012951435521245003 	 val loss 0.01375925075262785
# 	 partial train loss (single batch): 0.012965
# 	 partial train loss (single batch): 0.012575
# 	 partial train loss (single batch): 0.012683
# 	 partial train loss (single batch): 0.013004
# 	 partial train loss (single batch): 0.012824
# 	 partial train loss (single batch): 0.012707
# 	 partial train loss (single batch): 0.012814
# 	 partial train loss (single batch): 0.012826
# 	 partial train loss (single batch): 0.012903
# 	 partial train loss (single batch): 0.012922
# 	 partial train loss (single batch): 0.012878
# 	 partial train loss (single batch): 0.012857
# 	 partial train loss (single batch): 0.012782
# 	 partial train loss (single batch): 0.012730
# 	 partial train loss (single batch): 0.013150
# 	 partial train loss (single batch): 0.013436
# 	 partial train loss (single batch): 0.012700
# 	 partial train loss (single batch): 0.012873
# 	 partial train loss (single batch): 0.012903
# 	 partial train loss (single batch): 0.012589
# 	 partial train loss (single batch): 0.012941
# 	 partial train loss (single batch): 0.012926
# 	 partial train loss (single batch): 0.013114
# 	 partial train loss (single batch): 0.012932
# 	 partial train loss (single batch): 0.012922
# 	 partial train loss (single batch): 0.012775
# 	 partial train loss (single batch): 0.012678
# 	 partial train loss (single batch): 0.012859
# 	 partial train loss (single batch): 0.012559
# 	 partial train loss (single batch): 0.012674
# 	 partial train loss (single batch): 0.012895
# 	 partial train loss (single batch): 0.012598
# 	 partial train loss (single batch): 0.012599
# 	 partial train loss (single batch): 0.012915
# 	 partial train loss (single batch): 0.012667
# 	 partial train loss (single batch): 0.012645
# 	 partial train loss (single batch): 0.013003
# 	 partial train loss (single batch): 0.012676
# 	 partial train loss (single batch): 0.013163
# 	 partial train loss (single batch): 0.013445
# 	 partial train loss (single batch): 0.012795
# 	 partial train loss (single batch): 0.013192
# 	 partial train loss (single batch): 0.012325
# 	 partial train loss (single batch): 0.012692
# 	 partial train loss (single batch): 0.012588
# 	 partial train loss (single batch): 0.012375
# 	 partial train loss (single batch): 0.012524
# 	 partial train loss (single batch): 0.012686
# 	 partial train loss (single batch): 0.013478
# 	 partial train loss (single batch): 0.012839
# 	 partial train loss (single batch): 0.012369
# 	 partial train loss (single batch): 0.013128
# 	 partial train loss (single batch): 0.012588
# 	 partial train loss (single batch): 0.012639
# 	 partial train loss (single batch): 0.012902
# 	 partial train loss (single batch): 0.012938
# 	 partial train loss (single batch): 0.012514
# 	 partial train loss (single batch): 0.012371
# 	 partial train loss (single batch): 0.013129
# 	 partial train loss (single batch): 0.012674
# 	 partial train loss (single batch): 0.013045
# 	 partial train loss (single batch): 0.013141
# 	 partial train loss (single batch): 0.013032
# 	 partial train loss (single batch): 0.013201
# 	 partial train loss (single batch): 0.013125
# 	 partial train loss (single batch): 0.012726
# 	 partial train loss (single batch): 0.012663
# 	 partial train loss (single batch): 0.012936
# 	 partial train loss (single batch): 0.012575
# 	 partial train loss (single batch): 0.012349
# 	 partial train loss (single batch): 0.013112
# 	 partial train loss (single batch): 0.012525
# 	 partial train loss (single batch): 0.013020
# 	 partial train loss (single batch): 0.012985
# 	 partial train loss (single batch): 0.012818
# 	 partial train loss (single batch): 0.013523
# 	 partial train loss (single batch): 0.012459
# 	 partial train loss (single batch): 0.012603
# 	 partial train loss (single batch): 0.012523
# 	 partial train loss (single batch): 0.012931
# 	 partial train loss (single batch): 0.012844
# 	 partial train loss (single batch): 0.012889
# 	 partial train loss (single batch): 0.012899
# 	 partial train loss (single batch): 0.013735
# 	 partial train loss (single batch): 0.012813
# 	 partial train loss (single batch): 0.012813
# 	 partial train loss (single batch): 0.012940
# 	 partial train loss (single batch): 0.012857
# 	 partial train loss (single batch): 0.012662
# 	 partial train loss (single batch): 0.013136
# 	 partial train loss (single batch): 0.013438
# 	 partial train loss (single batch): 0.012699
# 	 partial train loss (single batch): 0.012611
# 	 partial train loss (single batch): 0.012745
# 	 partial train loss (single batch): 0.012858
# 	 partial train loss (single batch): 0.012945
# 	 partial train loss (single batch): 0.013029
# 	 partial train loss (single batch): 0.012567
# 	 partial train loss (single batch): 0.012710
# 	 partial train loss (single batch): 0.012568
# 	 partial train loss (single batch): 0.012800
# 	 partial train loss (single batch): 0.012908
# 	 partial train loss (single batch): 0.012968
# 	 partial train loss (single batch): 0.012800
# 	 partial train loss (single batch): 0.012749
# 	 partial train loss (single batch): 0.012864
# 	 partial train loss (single batch): 0.012835
# 	 partial train loss (single batch): 0.012907
# 	 partial train loss (single batch): 0.012756
# 	 partial train loss (single batch): 0.012843
# 	 partial train loss (single batch): 0.012395
# 	 partial train loss (single batch): 0.013193
# 	 partial train loss (single batch): 0.012758
# 	 partial train loss (single batch): 0.012903
# 	 partial train loss (single batch): 0.012052
#
#  EPOCH 3/10 	 train loss 0.01283158641308546 	 val loss 0.028858119621872902
# 	 partial train loss (single batch): 0.012890
# 	 partial train loss (single batch): 0.012514
# 	 partial train loss (single batch): 0.012610
# 	 partial train loss (single batch): 0.012935
# 	 partial train loss (single batch): 0.012754
# 	 partial train loss (single batch): 0.012634
# 	 partial train loss (single batch): 0.012756
# 	 partial train loss (single batch): 0.012748
# 	 partial train loss (single batch): 0.012820
# 	 partial train loss (single batch): 0.012835
# 	 partial train loss (single batch): 0.012797
# 	 partial train loss (single batch): 0.012766
# 	 partial train loss (single batch): 0.012701
# 	 partial train loss (single batch): 0.012653
# 	 partial train loss (single batch): 0.013073
# 	 partial train loss (single batch): 0.013358
# 	 partial train loss (single batch): 0.012626
# 	 partial train loss (single batch): 0.012802
# 	 partial train loss (single batch): 0.012851
# 	 partial train loss (single batch): 0.012520
# 	 partial train loss (single batch): 0.012886
# 	 partial train loss (single batch): 0.012839
# 	 partial train loss (single batch): 0.013055
# 	 partial train loss (single batch): 0.012871
# 	 partial train loss (single batch): 0.012844
# 	 partial train loss (single batch): 0.012718
# 	 partial train loss (single batch): 0.012615
# 	 partial train loss (single batch): 0.012811
# 	 partial train loss (single batch): 0.012492
# 	 partial train loss (single batch): 0.012601
# 	 partial train loss (single batch): 0.012839
# 	 partial train loss (single batch): 0.012547
# 	 partial train loss (single batch): 0.012548
# 	 partial train loss (single batch): 0.012848
# 	 partial train loss (single batch): 0.012595
# 	 partial train loss (single batch): 0.012586
# 	 partial train loss (single batch): 0.012955
# 	 partial train loss (single batch): 0.012628
# 	 partial train loss (single batch): 0.013084
# 	 partial train loss (single batch): 0.013381
# 	 partial train loss (single batch): 0.012739
# 	 partial train loss (single batch): 0.013147
# 	 partial train loss (single batch): 0.012276
# 	 partial train loss (single batch): 0.012637
# 	 partial train loss (single batch): 0.012543
# 	 partial train loss (single batch): 0.012323
# 	 partial train loss (single batch): 0.012463
# 	 partial train loss (single batch): 0.012630
# 	 partial train loss (single batch): 0.013416
# 	 partial train loss (single batch): 0.012783
# 	 partial train loss (single batch): 0.012326
# 	 partial train loss (single batch): 0.013055
# 	 partial train loss (single batch): 0.012522
# 	 partial train loss (single batch): 0.012580
# 	 partial train loss (single batch): 0.012840
# 	 partial train loss (single batch): 0.012855
# 	 partial train loss (single batch): 0.012426
# 	 partial train loss (single batch): 0.012271
# 	 partial train loss (single batch): 0.013060
# 	 partial train loss (single batch): 0.012771
# 	 partial train loss (single batch): 0.012965
# 	 partial train loss (single batch): 0.013079
# 	 partial train loss (single batch): 0.013038
# 	 partial train loss (single batch): 0.013156
# 	 partial train loss (single batch): 0.013078
# 	 partial train loss (single batch): 0.012697
# 	 partial train loss (single batch): 0.012627
# 	 partial train loss (single batch): 0.012894
# 	 partial train loss (single batch): 0.012528
# 	 partial train loss (single batch): 0.012292
# 	 partial train loss (single batch): 0.013065
# 	 partial train loss (single batch): 0.012494
# 	 partial train loss (single batch): 0.012975
# 	 partial train loss (single batch): 0.012935
# 	 partial train loss (single batch): 0.012772
# 	 partial train loss (single batch): 0.013484
# 	 partial train loss (single batch): 0.012416
# 	 partial train loss (single batch): 0.012567
# 	 partial train loss (single batch): 0.012483
# 	 partial train loss (single batch): 0.012896
# 	 partial train loss (single batch): 0.012802
# 	 partial train loss (single batch): 0.012834
# 	 partial train loss (single batch): 0.012858
# 	 partial train loss (single batch): 0.013680
# 	 partial train loss (single batch): 0.012758
# 	 partial train loss (single batch): 0.012757
# 	 partial train loss (single batch): 0.012879
# 	 partial train loss (single batch): 0.012782
# 	 partial train loss (single batch): 0.012597
# 	 partial train loss (single batch): 0.013041
# 	 partial train loss (single batch): 0.013318
# 	 partial train loss (single batch): 0.012507
# 	 partial train loss (single batch): 0.012411
# 	 partial train loss (single batch): 0.012569
# 	 partial train loss (single batch): 0.013721
# 	 partial train loss (single batch): 0.012925
# 	 partial train loss (single batch): 0.013146
# 	 partial train loss (single batch): 0.012599
# 	 partial train loss (single batch): 0.012712
# 	 partial train loss (single batch): 0.012591
# 	 partial train loss (single batch): 0.012801
# 	 partial train loss (single batch): 0.012933
# 	 partial train loss (single batch): 0.012964
# 	 partial train loss (single batch): 0.012757
# 	 partial train loss (single batch): 0.012741
# 	 partial train loss (single batch): 0.012861
# 	 partial train loss (single batch): 0.012838
# 	 partial train loss (single batch): 0.012910
# 	 partial train loss (single batch): 0.012767
# 	 partial train loss (single batch): 0.012817
# 	 partial train loss (single batch): 0.012306
# 	 partial train loss (single batch): 0.013187
# 	 partial train loss (single batch): 0.012657
# 	 partial train loss (single batch): 0.012849
# 	 partial train loss (single batch): 0.012004
#
#  EPOCH 4/10 	 train loss 0.012785824947059155 	 val loss 0.013711855746805668
# 	 partial train loss (single batch): 0.012836
# 	 partial train loss (single batch): 0.012459
# 	 partial train loss (single batch): 0.012571
# 	 partial train loss (single batch): 0.012885
# 	 partial train loss (single batch): 0.012702
# 	 partial train loss (single batch): 0.012546
# 	 partial train loss (single batch): 0.012683
# 	 partial train loss (single batch): 0.012668
# 	 partial train loss (single batch): 0.012717
# 	 partial train loss (single batch): 0.012725
# 	 partial train loss (single batch): 0.012607
# 	 partial train loss (single batch): 0.012572
# 	 partial train loss (single batch): 0.012465
# 	 partial train loss (single batch): 0.012416
# 	 partial train loss (single batch): 0.012918
# 	 partial train loss (single batch): 0.013371
# 	 partial train loss (single batch): 0.012434
# 	 partial train loss (single batch): 0.012809
# 	 partial train loss (single batch): 0.012652
# 	 partial train loss (single batch): 0.012426
# 	 partial train loss (single batch): 0.012710
# 	 partial train loss (single batch): 0.012623
# 	 partial train loss (single batch): 0.012977
# 	 partial train loss (single batch): 0.012664
# 	 partial train loss (single batch): 0.012647
# 	 partial train loss (single batch): 0.012469
# 	 partial train loss (single batch): 0.012407
# 	 partial train loss (single batch): 0.012576
# 	 partial train loss (single batch): 0.012300
# 	 partial train loss (single batch): 0.012323
# 	 partial train loss (single batch): 0.012477
# 	 partial train loss (single batch): 0.012176
# 	 partial train loss (single batch): 0.012185
# 	 partial train loss (single batch): 0.012509
# 	 partial train loss (single batch): 0.012292
# 	 partial train loss (single batch): 0.012316
# 	 partial train loss (single batch): 0.012592
# 	 partial train loss (single batch): 0.012266
# 	 partial train loss (single batch): 0.012861
# 	 partial train loss (single batch): 0.013030
# 	 partial train loss (single batch): 0.012364
# 	 partial train loss (single batch): 0.012728
# 	 partial train loss (single batch): 0.011881
# 	 partial train loss (single batch): 0.012344
# 	 partial train loss (single batch): 0.012252
# 	 partial train loss (single batch): 0.012018
# 	 partial train loss (single batch): 0.012170
# 	 partial train loss (single batch): 0.012370
# 	 partial train loss (single batch): 0.013021
# 	 partial train loss (single batch): 0.012373
# 	 partial train loss (single batch): 0.012006
# 	 partial train loss (single batch): 0.012731
# 	 partial train loss (single batch): 0.012230
# 	 partial train loss (single batch): 0.012256
# 	 partial train loss (single batch): 0.012565
# 	 partial train loss (single batch): 0.012591
# 	 partial train loss (single batch): 0.012084
# 	 partial train loss (single batch): 0.012126
# 	 partial train loss (single batch): 0.012624
# 	 partial train loss (single batch): 0.012328
# 	 partial train loss (single batch): 0.012689
# 	 partial train loss (single batch): 0.012719
# 	 partial train loss (single batch): 0.012628
# 	 partial train loss (single batch): 0.012826
# 	 partial train loss (single batch): 0.012600
# 	 partial train loss (single batch): 0.012336
# 	 partial train loss (single batch): 0.012287
# 	 partial train loss (single batch): 0.012549
# 	 partial train loss (single batch): 0.012175
# 	 partial train loss (single batch): 0.011948
# 	 partial train loss (single batch): 0.012735
# 	 partial train loss (single batch): 0.012037
# 	 partial train loss (single batch): 0.012666
# 	 partial train loss (single batch): 0.012475
# 	 partial train loss (single batch): 0.012462
# 	 partial train loss (single batch): 0.013083
# 	 partial train loss (single batch): 0.012081
# 	 partial train loss (single batch): 0.012161
# 	 partial train loss (single batch): 0.012135
# 	 partial train loss (single batch): 0.012528
# 	 partial train loss (single batch): 0.012416
# 	 partial train loss (single batch): 0.012354
# 	 partial train loss (single batch): 0.012558
# 	 partial train loss (single batch): 0.013245
# 	 partial train loss (single batch): 0.012396
# 	 partial train loss (single batch): 0.012381
# 	 partial train loss (single batch): 0.012530
# 	 partial train loss (single batch): 0.012387
# 	 partial train loss (single batch): 0.012297
# 	 partial train loss (single batch): 0.012682
# 	 partial train loss (single batch): 0.012951
# 	 partial train loss (single batch): 0.012246
# 	 partial train loss (single batch): 0.012272
# 	 partial train loss (single batch): 0.012363
# 	 partial train loss (single batch): 0.012492
# 	 partial train loss (single batch): 0.012508
# 	 partial train loss (single batch): 0.012566
# 	 partial train loss (single batch): 0.012154
# 	 partial train loss (single batch): 0.012291
# 	 partial train loss (single batch): 0.012191
# 	 partial train loss (single batch): 0.012381
# 	 partial train loss (single batch): 0.012580
# 	 partial train loss (single batch): 0.012511
# 	 partial train loss (single batch): 0.012335
# 	 partial train loss (single batch): 0.012267
# 	 partial train loss (single batch): 0.012510
# 	 partial train loss (single batch): 0.012462
# 	 partial train loss (single batch): 0.012467
# 	 partial train loss (single batch): 0.012428
# 	 partial train loss (single batch): 0.012404
# 	 partial train loss (single batch): 0.011918
# 	 partial train loss (single batch): 0.012712
# 	 partial train loss (single batch): 0.012238
# 	 partial train loss (single batch): 0.012482
# 	 partial train loss (single batch): 0.011706
#
#  EPOCH 5/10 	 train loss 0.012475864961743355 	 val loss 0.013735542073845863
# 	 partial train loss (single batch): 0.012462
# 	 partial train loss (single batch): 0.012108
# 	 partial train loss (single batch): 0.012221
# 	 partial train loss (single batch): 0.012502
# 	 partial train loss (single batch): 0.012309
# 	 partial train loss (single batch): 0.012189
# 	 partial train loss (single batch): 0.012323
# 	 partial train loss (single batch): 0.012355
# 	 partial train loss (single batch): 0.012382
# 	 partial train loss (single batch): 0.012391
# 	 partial train loss (single batch): 0.012288
# 	 partial train loss (single batch): 0.012412
# 	 partial train loss (single batch): 0.012253
# 	 partial train loss (single batch): 0.012223
# 	 partial train loss (single batch): 0.012636
# 	 partial train loss (single batch): 0.012929
# 	 partial train loss (single batch): 0.012235
# 	 partial train loss (single batch): 0.012364
# 	 partial train loss (single batch): 0.012449
# 	 partial train loss (single batch): 0.012112
# 	 partial train loss (single batch): 0.012389
# 	 partial train loss (single batch): 0.012468
# 	 partial train loss (single batch): 0.012674
# 	 partial train loss (single batch): 0.012514
# 	 partial train loss (single batch): 0.012446
# 	 partial train loss (single batch): 0.012231
# 	 partial train loss (single batch): 0.012263
# 	 partial train loss (single batch): 0.012484
# 	 partial train loss (single batch): 0.012084
# 	 partial train loss (single batch): 0.012182
# 	 partial train loss (single batch): 0.012355
# 	 partial train loss (single batch): 0.011987
# 	 partial train loss (single batch): 0.012128
# 	 partial train loss (single batch): 0.012366
# 	 partial train loss (single batch): 0.012170
# 	 partial train loss (single batch): 0.012193
# 	 partial train loss (single batch): 0.012503
# 	 partial train loss (single batch): 0.012163
# 	 partial train loss (single batch): 0.012755
# 	 partial train loss (single batch): 0.012912
# 	 partial train loss (single batch): 0.012295
# 	 partial train loss (single batch): 0.012629
# 	 partial train loss (single batch): 0.011814
# 	 partial train loss (single batch): 0.012227
# 	 partial train loss (single batch): 0.012202
# 	 partial train loss (single batch): 0.011902
# 	 partial train loss (single batch): 0.012073
# 	 partial train loss (single batch): 0.012265
# 	 partial train loss (single batch): 0.012932
# 	 partial train loss (single batch): 0.012351
# 	 partial train loss (single batch): 0.011945
# 	 partial train loss (single batch): 0.012708
# 	 partial train loss (single batch): 0.012153
# 	 partial train loss (single batch): 0.012163
# 	 partial train loss (single batch): 0.012437
# 	 partial train loss (single batch): 0.012414
# 	 partial train loss (single batch): 0.012010
# 	 partial train loss (single batch): 0.012001
# 	 partial train loss (single batch): 0.012512
# 	 partial train loss (single batch): 0.012228
# 	 partial train loss (single batch): 0.012562
# 	 partial train loss (single batch): 0.012586
# 	 partial train loss (single batch): 0.012584
# 	 partial train loss (single batch): 0.012758
# 	 partial train loss (single batch): 0.012540
# 	 partial train loss (single batch): 0.012324
# 	 partial train loss (single batch): 0.012248
# 	 partial train loss (single batch): 0.012483
# 	 partial train loss (single batch): 0.012067
# 	 partial train loss (single batch): 0.011852
# 	 partial train loss (single batch): 0.012630
# 	 partial train loss (single batch): 0.011974
# 	 partial train loss (single batch): 0.012622
# 	 partial train loss (single batch): 0.012412
# 	 partial train loss (single batch): 0.012410
# 	 partial train loss (single batch): 0.012962
# 	 partial train loss (single batch): 0.012012
# 	 partial train loss (single batch): 0.012116
# 	 partial train loss (single batch): 0.012096
# 	 partial train loss (single batch): 0.012450
# 	 partial train loss (single batch): 0.012393
# 	 partial train loss (single batch): 0.012272
# 	 partial train loss (single batch): 0.012480
# 	 partial train loss (single batch): 0.013155
# 	 partial train loss (single batch): 0.012389
# 	 partial train loss (single batch): 0.012372
# 	 partial train loss (single batch): 0.012475
# 	 partial train loss (single batch): 0.012305
# 	 partial train loss (single batch): 0.012243
# 	 partial train loss (single batch): 0.012608
# 	 partial train loss (single batch): 0.012914
# 	 partial train loss (single batch): 0.012131
# 	 partial train loss (single batch): 0.012215
# 	 partial train loss (single batch): 0.012407
# 	 partial train loss (single batch): 0.012544
# 	 partial train loss (single batch): 0.012475
# 	 partial train loss (single batch): 0.012558
# 	 partial train loss (single batch): 0.012094
# 	 partial train loss (single batch): 0.012298
# 	 partial train loss (single batch): 0.012211
# 	 partial train loss (single batch): 0.012304
# 	 partial train loss (single batch): 0.012541
# 	 partial train loss (single batch): 0.012459
# 	 partial train loss (single batch): 0.012243
# 	 partial train loss (single batch): 0.012182
# 	 partial train loss (single batch): 0.012386
# 	 partial train loss (single batch): 0.012283
# 	 partial train loss (single batch): 0.012260
# 	 partial train loss (single batch): 0.012168
# 	 partial train loss (single batch): 0.012516
# 	 partial train loss (single batch): 0.012328
# 	 partial train loss (single batch): 0.012583
# 	 partial train loss (single batch): 0.012302
# 	 partial train loss (single batch): 0.012470
# 	 partial train loss (single batch): 0.011635
#
#  EPOCH 6/10 	 train loss 0.012352719902992249 	 val loss 0.022719725966453552
# 	 partial train loss (single batch): 0.012405
# 	 partial train loss (single batch): 0.012008
# 	 partial train loss (single batch): 0.011987
# 	 partial train loss (single batch): 0.012268
# 	 partial train loss (single batch): 0.012077
# 	 partial train loss (single batch): 0.011939
# 	 partial train loss (single batch): 0.012029
# 	 partial train loss (single batch): 0.012004
# 	 partial train loss (single batch): 0.012123
# 	 partial train loss (single batch): 0.012037
# 	 partial train loss (single batch): 0.011940
# 	 partial train loss (single batch): 0.012084
# 	 partial train loss (single batch): 0.011950
# 	 partial train loss (single batch): 0.011895
# 	 partial train loss (single batch): 0.012268
# 	 partial train loss (single batch): 0.012503
# 	 partial train loss (single batch): 0.011874
# 	 partial train loss (single batch): 0.011976
# 	 partial train loss (single batch): 0.012071
# 	 partial train loss (single batch): 0.011617
# 	 partial train loss (single batch): 0.012007
# 	 partial train loss (single batch): 0.012106
# 	 partial train loss (single batch): 0.012171
# 	 partial train loss (single batch): 0.012070
# 	 partial train loss (single batch): 0.012127
# 	 partial train loss (single batch): 0.011763
# 	 partial train loss (single batch): 0.011911
# 	 partial train loss (single batch): 0.012110
# 	 partial train loss (single batch): 0.011818
# 	 partial train loss (single batch): 0.011767
# 	 partial train loss (single batch): 0.012011
# 	 partial train loss (single batch): 0.011571
# 	 partial train loss (single batch): 0.011689
# 	 partial train loss (single batch): 0.011988
# 	 partial train loss (single batch): 0.011793
# 	 partial train loss (single batch): 0.011891
# 	 partial train loss (single batch): 0.012131
# 	 partial train loss (single batch): 0.011675
# 	 partial train loss (single batch): 0.012357
# 	 partial train loss (single batch): 0.012493
# 	 partial train loss (single batch): 0.011811
# 	 partial train loss (single batch): 0.012200
# 	 partial train loss (single batch): 0.011458
# 	 partial train loss (single batch): 0.011831
# 	 partial train loss (single batch): 0.011775
# 	 partial train loss (single batch): 0.011489
# 	 partial train loss (single batch): 0.011640
# 	 partial train loss (single batch): 0.011879
# 	 partial train loss (single batch): 0.012358
# 	 partial train loss (single batch): 0.011927
# 	 partial train loss (single batch): 0.011578
# 	 partial train loss (single batch): 0.012257
# 	 partial train loss (single batch): 0.011807
# 	 partial train loss (single batch): 0.011809
# 	 partial train loss (single batch): 0.012183
# 	 partial train loss (single batch): 0.011935
# 	 partial train loss (single batch): 0.011533
# 	 partial train loss (single batch): 0.011594
# 	 partial train loss (single batch): 0.012007
# 	 partial train loss (single batch): 0.011770
# 	 partial train loss (single batch): 0.012112
# 	 partial train loss (single batch): 0.012160
# 	 partial train loss (single batch): 0.012044
# 	 partial train loss (single batch): 0.012291
# 	 partial train loss (single batch): 0.012078
# 	 partial train loss (single batch): 0.011896
# 	 partial train loss (single batch): 0.011756
# 	 partial train loss (single batch): 0.012018
# 	 partial train loss (single batch): 0.011664
# 	 partial train loss (single batch): 0.011495
# 	 partial train loss (single batch): 0.012117
# 	 partial train loss (single batch): 0.011479
# 	 partial train loss (single batch): 0.012058
# 	 partial train loss (single batch): 0.011955
# 	 partial train loss (single batch): 0.012003
# 	 partial train loss (single batch): 0.012384
# 	 partial train loss (single batch): 0.011649
# 	 partial train loss (single batch): 0.011589
# 	 partial train loss (single batch): 0.011731
# 	 partial train loss (single batch): 0.012039
# 	 partial train loss (single batch): 0.012052
# 	 partial train loss (single batch): 0.011812
# 	 partial train loss (single batch): 0.012091
# 	 partial train loss (single batch): 0.012630
# 	 partial train loss (single batch): 0.011966
# 	 partial train loss (single batch): 0.011881
# 	 partial train loss (single batch): 0.011982
# 	 partial train loss (single batch): 0.011908
# 	 partial train loss (single batch): 0.011941
# 	 partial train loss (single batch): 0.012153
# 	 partial train loss (single batch): 0.012473
# 	 partial train loss (single batch): 0.011747
# 	 partial train loss (single batch): 0.011726
# 	 partial train loss (single batch): 0.011958
# 	 partial train loss (single batch): 0.012043
# 	 partial train loss (single batch): 0.011965
# 	 partial train loss (single batch): 0.012040
# 	 partial train loss (single batch): 0.011700
# 	 partial train loss (single batch): 0.011780
# 	 partial train loss (single batch): 0.011732
# 	 partial train loss (single batch): 0.011811
# 	 partial train loss (single batch): 0.012204
# 	 partial train loss (single batch): 0.011916
# 	 partial train loss (single batch): 0.011859
# 	 partial train loss (single batch): 0.011751
# 	 partial train loss (single batch): 0.011964
# 	 partial train loss (single batch): 0.011928
# 	 partial train loss (single batch): 0.012023
# 	 partial train loss (single batch): 0.011953
# 	 partial train loss (single batch): 0.011913
# 	 partial train loss (single batch): 0.011433
# 	 partial train loss (single batch): 0.012123
# 	 partial train loss (single batch): 0.011769
# 	 partial train loss (single batch): 0.011928
# 	 partial train loss (single batch): 0.011172
#
#  EPOCH 7/10 	 train loss 0.011940778233110905 	 val loss 0.012115409597754478
# 	 partial train loss (single batch): 0.011945
# 	 partial train loss (single batch): 0.011702
# 	 partial train loss (single batch): 0.011562
# 	 partial train loss (single batch): 0.011912
# 	 partial train loss (single batch): 0.011720
# 	 partial train loss (single batch): 0.011502
# 	 partial train loss (single batch): 0.011777
# 	 partial train loss (single batch): 0.011745
# 	 partial train loss (single batch): 0.011776
# 	 partial train loss (single batch): 0.011700
# 	 partial train loss (single batch): 0.011557
# 	 partial train loss (single batch): 0.011692
# 	 partial train loss (single batch): 0.011945
# 	 partial train loss (single batch): 0.012383
# 	 partial train loss (single batch): 0.012654
# 	 partial train loss (single batch): 0.012956
# 	 partial train loss (single batch): 0.012188
# 	 partial train loss (single batch): 0.012189
# 	 partial train loss (single batch): 0.012229
# 	 partial train loss (single batch): 0.011815
# 	 partial train loss (single batch): 0.012211
# 	 partial train loss (single batch): 0.012111
# 	 partial train loss (single batch): 0.012220
# 	 partial train loss (single batch): 0.012067
# 	 partial train loss (single batch): 0.012199
# 	 partial train loss (single batch): 0.011681
# 	 partial train loss (single batch): 0.011787
# 	 partial train loss (single batch): 0.011967
# 	 partial train loss (single batch): 0.011665
# 	 partial train loss (single batch): 0.011606
# 	 partial train loss (single batch): 0.011745
# 	 partial train loss (single batch): 0.011344
# 	 partial train loss (single batch): 0.011490
# 	 partial train loss (single batch): 0.011739
# 	 partial train loss (single batch): 0.011537
# 	 partial train loss (single batch): 0.011589
# 	 partial train loss (single batch): 0.011721
# 	 partial train loss (single batch): 0.011489
# 	 partial train loss (single batch): 0.012055
# 	 partial train loss (single batch): 0.012142
# 	 partial train loss (single batch): 0.011506
# 	 partial train loss (single batch): 0.011866
# 	 partial train loss (single batch): 0.011080
# 	 partial train loss (single batch): 0.011428
# 	 partial train loss (single batch): 0.011413
# 	 partial train loss (single batch): 0.011148
# 	 partial train loss (single batch): 0.011279
# 	 partial train loss (single batch): 0.011581
# 	 partial train loss (single batch): 0.011820
# 	 partial train loss (single batch): 0.011560
# 	 partial train loss (single batch): 0.011260
# 	 partial train loss (single batch): 0.011700
# 	 partial train loss (single batch): 0.011430
# 	 partial train loss (single batch): 0.011461
# 	 partial train loss (single batch): 0.011746
# 	 partial train loss (single batch): 0.011575
# 	 partial train loss (single batch): 0.011137
# 	 partial train loss (single batch): 0.011155
# 	 partial train loss (single batch): 0.011624
# 	 partial train loss (single batch): 0.011310
# 	 partial train loss (single batch): 0.011705
# 	 partial train loss (single batch): 0.011741
# 	 partial train loss (single batch): 0.011549
# 	 partial train loss (single batch): 0.011830
# 	 partial train loss (single batch): 0.011591
# 	 partial train loss (single batch): 0.011509
# 	 partial train loss (single batch): 0.011399
# 	 partial train loss (single batch): 0.011550
# 	 partial train loss (single batch): 0.011275
# 	 partial train loss (single batch): 0.011102
# 	 partial train loss (single batch): 0.011687
# 	 partial train loss (single batch): 0.011109
# 	 partial train loss (single batch): 0.011656
# 	 partial train loss (single batch): 0.011531
# 	 partial train loss (single batch): 0.011592
# 	 partial train loss (single batch): 0.011962
# 	 partial train loss (single batch): 0.011272
# 	 partial train loss (single batch): 0.011151
# 	 partial train loss (single batch): 0.011382
# 	 partial train loss (single batch): 0.011623
# 	 partial train loss (single batch): 0.011672
# 	 partial train loss (single batch): 0.011375
# 	 partial train loss (single batch): 0.011594
# 	 partial train loss (single batch): 0.012057
# 	 partial train loss (single batch): 0.011485
# 	 partial train loss (single batch): 0.011450
# 	 partial train loss (single batch): 0.011656
# 	 partial train loss (single batch): 0.011427
# 	 partial train loss (single batch): 0.011446
# 	 partial train loss (single batch): 0.011790
# 	 partial train loss (single batch): 0.011962
# 	 partial train loss (single batch): 0.011402
# 	 partial train loss (single batch): 0.011352
# 	 partial train loss (single batch): 0.011548
# 	 partial train loss (single batch): 0.011750
# 	 partial train loss (single batch): 0.011565
# 	 partial train loss (single batch): 0.011609
# 	 partial train loss (single batch): 0.011356
# 	 partial train loss (single batch): 0.011440
# 	 partial train loss (single batch): 0.011390
# 	 partial train loss (single batch): 0.011407
# 	 partial train loss (single batch): 0.011824
# 	 partial train loss (single batch): 0.011560
# 	 partial train loss (single batch): 0.011364
# 	 partial train loss (single batch): 0.011298
# 	 partial train loss (single batch): 0.011480
# 	 partial train loss (single batch): 0.011484
# 	 partial train loss (single batch): 0.011635
# 	 partial train loss (single batch): 0.011577
# 	 partial train loss (single batch): 0.011591
# 	 partial train loss (single batch): 0.010993
# 	 partial train loss (single batch): 0.011677
# 	 partial train loss (single batch): 0.011425
# 	 partial train loss (single batch): 0.011422
# 	 partial train loss (single batch): 0.010808
#
#  EPOCH 8/10 	 train loss 0.011630257591605186 	 val loss 0.011995404958724976
# 	 partial train loss (single batch): 0.011565
# 	 partial train loss (single batch): 0.011428
# 	 partial train loss (single batch): 0.011256
# 	 partial train loss (single batch): 0.011597
# 	 partial train loss (single batch): 0.011448
# 	 partial train loss (single batch): 0.011217
# 	 partial train loss (single batch): 0.011431
# 	 partial train loss (single batch): 0.011474
# 	 partial train loss (single batch): 0.011468
# 	 partial train loss (single batch): 0.011469
# 	 partial train loss (single batch): 0.011357
# 	 partial train loss (single batch): 0.011499
# 	 partial train loss (single batch): 0.011470
# 	 partial train loss (single batch): 0.011344
# 	 partial train loss (single batch): 0.011700
# 	 partial train loss (single batch): 0.011843
# 	 partial train loss (single batch): 0.011270
# 	 partial train loss (single batch): 0.011436
# 	 partial train loss (single batch): 0.011483
# 	 partial train loss (single batch): 0.011166
# 	 partial train loss (single batch): 0.011487
# 	 partial train loss (single batch): 0.011663
# 	 partial train loss (single batch): 0.011664
# 	 partial train loss (single batch): 0.011531
# 	 partial train loss (single batch): 0.011652
# 	 partial train loss (single batch): 0.011166
# 	 partial train loss (single batch): 0.011371
# 	 partial train loss (single batch): 0.011631
# 	 partial train loss (single batch): 0.011348
# 	 partial train loss (single batch): 0.011278
# 	 partial train loss (single batch): 0.011492
# 	 partial train loss (single batch): 0.011116
# 	 partial train loss (single batch): 0.011289
# 	 partial train loss (single batch): 0.011507
# 	 partial train loss (single batch): 0.011261
# 	 partial train loss (single batch): 0.011363
# 	 partial train loss (single batch): 0.011545
# 	 partial train loss (single batch): 0.011310
# 	 partial train loss (single batch): 0.011933
# 	 partial train loss (single batch): 0.011983
# 	 partial train loss (single batch): 0.011360
# 	 partial train loss (single batch): 0.011728
# 	 partial train loss (single batch): 0.010949
# 	 partial train loss (single batch): 0.011306
# 	 partial train loss (single batch): 0.011287
# 	 partial train loss (single batch): 0.011002
# 	 partial train loss (single batch): 0.011160
# 	 partial train loss (single batch): 0.011454
# 	 partial train loss (single batch): 0.011690
# 	 partial train loss (single batch): 0.011464
# 	 partial train loss (single batch): 0.011161
# 	 partial train loss (single batch): 0.011567
# 	 partial train loss (single batch): 0.011385
# 	 partial train loss (single batch): 0.011398
# 	 partial train loss (single batch): 0.011649
# 	 partial train loss (single batch): 0.011523
# 	 partial train loss (single batch): 0.011073
# 	 partial train loss (single batch): 0.011074
# 	 partial train loss (single batch): 0.011555
# 	 partial train loss (single batch): 0.011277
# 	 partial train loss (single batch): 0.011651
# 	 partial train loss (single batch): 0.011661
# 	 partial train loss (single batch): 0.011493
# 	 partial train loss (single batch): 0.011738
# 	 partial train loss (single batch): 0.011542
# 	 partial train loss (single batch): 0.011425
# 	 partial train loss (single batch): 0.011325
# 	 partial train loss (single batch): 0.011526
# 	 partial train loss (single batch): 0.011212
# 	 partial train loss (single batch): 0.011062
# 	 partial train loss (single batch): 0.011624
# 	 partial train loss (single batch): 0.011048
# 	 partial train loss (single batch): 0.011635
# 	 partial train loss (single batch): 0.011447
# 	 partial train loss (single batch): 0.011500
# 	 partial train loss (single batch): 0.011885
# 	 partial train loss (single batch): 0.011196
# 	 partial train loss (single batch): 0.011055
# 	 partial train loss (single batch): 0.011203
# 	 partial train loss (single batch): 0.011443
# 	 partial train loss (single batch): 0.011481
# 	 partial train loss (single batch): 0.011386
# 	 partial train loss (single batch): 0.012157
# 	 partial train loss (single batch): 0.012217
# 	 partial train loss (single batch): 0.011503
# 	 partial train loss (single batch): 0.011585
# 	 partial train loss (single batch): 0.011563
# 	 partial train loss (single batch): 0.011307
# 	 partial train loss (single batch): 0.011384
# 	 partial train loss (single batch): 0.011627
# 	 partial train loss (single batch): 0.011896
# 	 partial train loss (single batch): 0.011236
# 	 partial train loss (single batch): 0.011227
# 	 partial train loss (single batch): 0.011306
# 	 partial train loss (single batch): 0.011489
# 	 partial train loss (single batch): 0.011335
# 	 partial train loss (single batch): 0.011361
# 	 partial train loss (single batch): 0.011097
# 	 partial train loss (single batch): 0.011145
# 	 partial train loss (single batch): 0.011079
# 	 partial train loss (single batch): 0.011040
# 	 partial train loss (single batch): 0.011483
# 	 partial train loss (single batch): 0.011183
# 	 partial train loss (single batch): 0.011047
# 	 partial train loss (single batch): 0.011064
# 	 partial train loss (single batch): 0.011190
# 	 partial train loss (single batch): 0.011206
# 	 partial train loss (single batch): 0.011316
# 	 partial train loss (single batch): 0.011276
# 	 partial train loss (single batch): 0.011181
# 	 partial train loss (single batch): 0.010676
# 	 partial train loss (single batch): 0.011348
# 	 partial train loss (single batch): 0.011077
# 	 partial train loss (single batch): 0.011033
# 	 partial train loss (single batch): 0.010462
#
#  EPOCH 9/10 	 train loss 0.011393162421882153 	 val loss 0.011272643692791462
# 	 partial train loss (single batch): 0.011196
# 	 partial train loss (single batch): 0.011092
# 	 partial train loss (single batch): 0.010836
# 	 partial train loss (single batch): 0.011182
# 	 partial train loss (single batch): 0.011128
# 	 partial train loss (single batch): 0.010835
# 	 partial train loss (single batch): 0.011069
# 	 partial train loss (single batch): 0.011074
# 	 partial train loss (single batch): 0.011184
# 	 partial train loss (single batch): 0.011067
# 	 partial train loss (single batch): 0.010900
# 	 partial train loss (single batch): 0.011139
# 	 partial train loss (single batch): 0.011085
# 	 partial train loss (single batch): 0.011007
# 	 partial train loss (single batch): 0.011297
# 	 partial train loss (single batch): 0.011419
# 	 partial train loss (single batch): 0.010922
# 	 partial train loss (single batch): 0.010981
# 	 partial train loss (single batch): 0.011038
# 	 partial train loss (single batch): 0.010799
# 	 partial train loss (single batch): 0.011095
# 	 partial train loss (single batch): 0.011288
# 	 partial train loss (single batch): 0.011201
# 	 partial train loss (single batch): 0.011128
# 	 partial train loss (single batch): 0.011212
# 	 partial train loss (single batch): 0.010819
# 	 partial train loss (single batch): 0.010927
# 	 partial train loss (single batch): 0.011219
# 	 partial train loss (single batch): 0.010941
# 	 partial train loss (single batch): 0.010895
# 	 partial train loss (single batch): 0.011082
# 	 partial train loss (single batch): 0.010678
# 	 partial train loss (single batch): 0.010934
# 	 partial train loss (single batch): 0.011071
# 	 partial train loss (single batch): 0.010805
# 	 partial train loss (single batch): 0.010950
# 	 partial train loss (single batch): 0.011133
# 	 partial train loss (single batch): 0.010900
# 	 partial train loss (single batch): 0.011375
# 	 partial train loss (single batch): 0.011318
# 	 partial train loss (single batch): 0.010898
# 	 partial train loss (single batch): 0.011313
# 	 partial train loss (single batch): 0.010721
# 	 partial train loss (single batch): 0.010930
# 	 partial train loss (single batch): 0.010876
# 	 partial train loss (single batch): 0.010767
# 	 partial train loss (single batch): 0.010658
# 	 partial train loss (single batch): 0.011010
# 	 partial train loss (single batch): 0.011317
# 	 partial train loss (single batch): 0.010995
# 	 partial train loss (single batch): 0.010685
# 	 partial train loss (single batch): 0.011018
# 	 partial train loss (single batch): 0.010818
# 	 partial train loss (single batch): 0.010921
# 	 partial train loss (single batch): 0.011176
# 	 partial train loss (single batch): 0.010979
# 	 partial train loss (single batch): 0.010679
# 	 partial train loss (single batch): 0.010567
# 	 partial train loss (single batch): 0.010942
# 	 partial train loss (single batch): 0.010742
# 	 partial train loss (single batch): 0.011065
# 	 partial train loss (single batch): 0.011134
# 	 partial train loss (single batch): 0.010988
# 	 partial train loss (single batch): 0.011230
# 	 partial train loss (single batch): 0.010967
# 	 partial train loss (single batch): 0.010922
# 	 partial train loss (single batch): 0.010757
# 	 partial train loss (single batch): 0.010922
# 	 partial train loss (single batch): 0.010548
# 	 partial train loss (single batch): 0.010494
# 	 partial train loss (single batch): 0.011025
# 	 partial train loss (single batch): 0.010465
# 	 partial train loss (single batch): 0.011002
# 	 partial train loss (single batch): 0.010780
# 	 partial train loss (single batch): 0.010872
# 	 partial train loss (single batch): 0.011221
# 	 partial train loss (single batch): 0.010603
# 	 partial train loss (single batch): 0.010448
# 	 partial train loss (single batch): 0.010714
# 	 partial train loss (single batch): 0.010982
# 	 partial train loss (single batch): 0.010905
# 	 partial train loss (single batch): 0.010827
# 	 partial train loss (single batch): 0.010946
# 	 partial train loss (single batch): 0.011363
# 	 partial train loss (single batch): 0.010876
# 	 partial train loss (single batch): 0.010839
# 	 partial train loss (single batch): 0.010917
# 	 partial train loss (single batch): 0.010812
# 	 partial train loss (single batch): 0.010816
# 	 partial train loss (single batch): 0.010998
# 	 partial train loss (single batch): 0.011331
# 	 partial train loss (single batch): 0.010712
# 	 partial train loss (single batch): 0.010688
# 	 partial train loss (single batch): 0.010904
# 	 partial train loss (single batch): 0.011091
# 	 partial train loss (single batch): 0.010901
# 	 partial train loss (single batch): 0.010947
# 	 partial train loss (single batch): 0.010655
# 	 partial train loss (single batch): 0.010761
# 	 partial train loss (single batch): 0.010707
# 	 partial train loss (single batch): 0.010655
# 	 partial train loss (single batch): 0.011176
# 	 partial train loss (single batch): 0.010689
# 	 partial train loss (single batch): 0.010729
# 	 partial train loss (single batch): 0.010751
# 	 partial train loss (single batch): 0.010877
# 	 partial train loss (single batch): 0.010852
# 	 partial train loss (single batch): 0.010916
# 	 partial train loss (single batch): 0.010924
# 	 partial train loss (single batch): 0.010818
# 	 partial train loss (single batch): 0.010402
# 	 partial train loss (single batch): 0.011084
# 	 partial train loss (single batch): 0.010791
# 	 partial train loss (single batch): 0.010725
# 	 partial train loss (single batch): 0.010155
#
#  EPOCH 10/10 	 train loss 0.010929702781140804 	 val loss 0.011277340352535248

# %%
test_epoch(encoder,decoder,device,test_loader,loss_fn).item()
# Out:
# 0.011277339421212673

# %%
# Plot losses
plt.figure(figsize=(10,8))
plt.semilogy(diz_loss['train_loss'], label='Train')
plt.semilogy(diz_loss['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
#plt.grid()
plt.legend()
#plt.title('loss')
plt.show()

# %% [markdown]
# # evaluate

# %%
encoder.eval()
decoder.eval()

with torch.no_grad():
    # calculate mean and std of latent code, generated takining in test images as inputs 
    images = next(iter(test_loader))
    images = (images.type('torch.FloatTensor')).to(device)
    latent = encoder(images)
    latent = latent.cpu()

# %% [markdown]
# ## Generate new samples from the random latent code
# To generate new images from the latent code, we sample randomly from a normal distribution with the mean and standard deviation of the encoded data. These samples will be passed to the decoder, which will create the reconstructed images.

# %%
#def show_image(img):
#    npimg = img.numpy()
#    plt.imshow(np.transpose(npimg, (1, 2, 0)))

encoder.eval()
decoder.eval()

with torch.no_grad():
    # calculate mean and std of latent code, generated takining in test images as inputs 
    images = next(iter(train_loader))
    images_cpu=images.cpu()
    images = (images.type('torch.FloatTensor')).to(device)
    latent = encoder(images)
    latent_mode= latent.cpu()
    latent_cpu = latent.cpu()
   
     
    print(latent_mode.shape)
    print(latent_cpu.shape)

    mode=[0]
    
    #for i in range(0,batch_size):
    #    for j in range(0,d):
    #        if j not in mode:
    #            latent_mode[i][j]=0
                
    latent_mode = latent_mode.to(device)
    
    img_recon = decoder(latent)
    img_recon_cpu = img_recon.cpu()
    
    mode_recon = decoder(latent_mode)
    mode_recon_cpu = mode_recon.cpu()
    
    
    print(img_recon_cpu[0].shape)
# Out:
# torch.Size([100, 1024])
# torch.Size([100, 1024])
# torch.Size([3, 64, 64])

# %%
plt.plot(latent_cpu.numpy()[:,0])
plt.show()

#show_image(mode_recon_cpu[0],all_comps)

# %%
show_image(images_cpu[10],all_comps)
show_image(img_recon_cpu[10],all_comps)

# %%
sys.exit(0)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /scratch/adperez/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3406: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # Visualize the latent space with t-SNE
# After we can observe dynamic visualization to see the latent space learned by the autoencoder. First, we create the encoded samples using the test set.

# %%
encoded_samples = []
for sample in tqdm(test_dataset):
    img = sample[0].unsqueeze(0).to(device)
    label = sample[1]
    # Encode image
    encoder.eval()
    with torch.no_grad():
        encoded_img  = encoder(img)
    # Append to list
    encoded_img = encoded_img.flatten().cpu().numpy()
    encoded_sample = {f"Enc. Variable {i}": enc for i, enc in enumerate(encoded_img)}
    encoded_sample['label'] = label
    encoded_samples.append(encoded_sample)
encoded_samples = pd.DataFrame(encoded_samples)
encoded_samples

# %%
class Encoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()
        
        ### Convolutional section
        self.encoder_cnn = nn.Sequential(
            nn.Conv2d(3, 8, 3, stride=2, padding=1),
            nn.ReLU(True),
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.Conv2d(16, 32, 3, stride=2, padding=1),
            nn.ReLU(True)
        )
        
        ### Flatten layer
        self.flatten = nn.Flatten(start_dim=1)
### Linear section
        self.encoder_lin = nn.Sequential(
            nn.Linear(32*8*8, 128),
            nn.ReLU(True),
            nn.Linear(128, encoded_space_dim)
        )
        
    def forward(self, x):
        x = self.encoder_cnn(x)
        #print(x.shape)
        x = self.flatten(x)
        #print(x.shape)
        x = self.encoder_lin(x)
        #print(x.shape)
        
        return x
class Decoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()
        self.decoder_lin = nn.Sequential(
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            nn.Linear(128, 32*8*8),
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, 
        unflattened_size=(32, 8, 8))

        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose2d(32, 16, 3, 
            stride=2,padding=1, output_padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.ConvTranspose2d(16, 8, 3, stride=2, 
            padding=1, output_padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            nn.ConvTranspose2d(8, 3, 3, stride=2, 
            padding=1, output_padding=1)
        )
        
    def forward(self, x):
        x = self.decoder_lin(x)
        #print(x.shape)
        x = self.unflatten(x) 
        #print(x.shape)
        x = self.decoder_conv(x)
        #print(x.shape)
        x = torch.sigmoid(x)
        return x
